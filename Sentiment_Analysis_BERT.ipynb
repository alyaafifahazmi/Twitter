# %% [markdown]
# <a href="https://colab.research.google.com/github/alyaafifahazmi/Twitter/blob/alyaafifahazmi-patch-2/Sentiment_Analysis_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/98/87/ef312eef26f5cecd8b17ae9654cdd8d1fae1eb6dbd87257d6d73c128a4d0/transformers-4.3.2-py3-none-any.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 15.0MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (1.19.5)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 55.4MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from transformers) (3.4.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/fd/5b/44baae602e0a30bcc53fbdbc60bd940c15e143d252d658dfdefce736ece5/tokenizers-0.10.1-cp36-cp36m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 55.2MB/s
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=10972f21298466874269bc156b7b335cdcc7466c373170245c2618bd4ad5c47d
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.10.1 transformers-4.3.2

# %%
from transformers import BertTokenizer, TFBertForSequenceClassification
from transformers import InputExample, InputFeatures

model = TFBertForSequenceClassification.from_pretrained("bert-base-uncased")
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=433.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=536063208.0, style=ProgressStyle(descri…
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…

# %%
model.summary()
# Out:
# Model: "tf_bert_for_sequence_classification"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bert (TFBertMainLayer)       multiple                  109482240
# _________________________________________________________________
# dropout_37 (Dropout)         multiple                  0
# _________________________________________________________________
# classifier (Dense)           multiple                  1538
# =================================================================
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
import pandas as pd

# %%
URL = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

dataset = tf.keras.utils.get_file(fname="aclImdb_v1.tar.gz", 
                                  origin=URL,
                                  untar=True,
                                  cache_dir='.',
                                  cache_subdir='')
# Out:
# Downloading data from https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# 84131840/84125825 [==============================] - 4s 0us/step

# %%
# The shutil module offers a number of high-level 
# operations on files and collections of files.
import os
import shutil
# Create main directory path ("/aclImdb")
main_dir = os.path.join(os.path.dirname(dataset), 'aclImdb')
# Create sub directory path ("/aclImdb/train")
train_dir = os.path.join(main_dir, 'train')
# Remove unsup folder since this is a supervised learning task
remove_dir = os.path.join(train_dir, 'unsup')
shutil.rmtree(remove_dir)
# View the final train folder
print(os.listdir(train_dir))
# Out:
# ['urls_unsup.txt', 'pos', 'urls_pos.txt', 'neg', 'labeledBow.feat', 'unsupBow.feat', 'urls_neg.txt']

# %%
# We create a training dataset and a validation 
# dataset from our "aclImdb/train" directory with a 80/20 split.
train = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train', batch_size=30000, validation_split=0.2, 
    subset='training', seed=123)
test = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train', batch_size=30000, validation_split=0.2, 
  subset='validation', seed=123)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.

# %%
for i in train.take(1):
  train_feat = i[0].numpy()
  train_lab = i[1].numpy()

train = pd.DataFrame([train_feat, train_lab]).T
train.columns = ['DATA_COLUMN', 'LABEL_COLUMN']
train['DATA_COLUMN'] = train['DATA_COLUMN'].str.decode("utf-8")
train.head()
# Out:
#                                          DATA_COLUMN LABEL_COLUMN
# 0  Canadian director Vincenzo Natali took the art...            1
# 1  I gave this film 10 not because it is a superb...            1
# 2  I admit to being somewhat jaded about the movi...            1
# 3  For a long time, 'The Menagerie' was my favori...            1
# 4  A truly frightening film. Feels as if it were ...            0

# %%
for j in test.take(1):
  test_feat = j[0].numpy()
  test_lab = j[1].numpy()

test = pd.DataFrame([test_feat, test_lab]).T
test.columns = ['DATA_COLUMN', 'LABEL_COLUMN']
test['DATA_COLUMN'] = test['DATA_COLUMN'].str.decode("utf-8")
test.head()
# Out:
#                                          DATA_COLUMN LABEL_COLUMN
# 0  I can't believe that so much talent can be was...            0
# 1  This movie blows - let's get that straight rig...            0
# 2  The saddest thing about this "tribute" is that...            0
# 3  I'm only rating this film as a 3 out of pity b...            0
# 4  Something surprised me about this movie - it w...            1

# %%
def convert_data_to_examples(train, test, DATA_COLUMN, LABEL_COLUMN): 
  train_InputExamples = train.apply(lambda x: InputExample(guid=None, # Globally unique ID for bookkeeping, unused in this case
                                                          text_a = x[DATA_COLUMN], 
                                                          text_b = None,
                                                          label = x[LABEL_COLUMN]), axis = 1)

  validation_InputExamples = test.apply(lambda x: InputExample(guid=None, # Globally unique ID for bookkeeping, unused in this case
                                                          text_a = x[DATA_COLUMN], 
                                                          text_b = None,
                                                          label = x[LABEL_COLUMN]), axis = 1)
  
  return train_InputExamples, validation_InputExamples

  train_InputExamples, validation_InputExamples = convert_data_to_examples(train, 
                                                                           test, 
                                                                           'DATA_COLUMN', 
                                                                           'LABEL_COLUMN')
  
def convert_examples_to_tf_dataset(examples, tokenizer, max_length=128):
    features = [] # -> will hold InputFeatures to be converted later

    for e in examples:
        # Documentation is really strong for this method, so please take a look at it
        input_dict = tokenizer.encode_plus(
            e.text_a,
            add_special_tokens=True,
            max_length=max_length, # truncates if len(s) > max_length
            return_token_type_ids=True,
            return_attention_mask=True,
            pad_to_max_length=True, # pads to the right by default # CHECK THIS for pad_to_max_length
            truncation=True
        )

        input_ids, token_type_ids, attention_mask = (input_dict["input_ids"],
            input_dict["token_type_ids"], input_dict['attention_mask'])

        features.append(
            InputFeatures(
                input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids, label=e.label
            )
        )

    def gen():
        for f in features:
            yield (
                {
                    "input_ids": f.input_ids,
                    "attention_mask": f.attention_mask,
                    "token_type_ids": f.token_type_ids,
                },
                f.label,
            )

    return tf.data.Dataset.from_generator(
        gen,
        ({"input_ids": tf.int32, "attention_mask": tf.int32, "token_type_ids": tf.int32}, tf.int64),
        (
            {
                "input_ids": tf.TensorShape([None]),
                "attention_mask": tf.TensorShape([None]),
                "token_type_ids": tf.TensorShape([None]),
            },
            tf.TensorShape([]),
        ),
    )


DATA_COLUMN = 'DATA_COLUMN'
LABEL_COLUMN = 'LABEL_COLUMN'

# %%
train_InputExamples, validation_InputExamples = convert_data_to_examples(train, test, DATA_COLUMN, LABEL_COLUMN)

train_data = convert_examples_to_tf_dataset(list(train_InputExamples), tokenizer)
train_data = train_data.shuffle(100).batch(32).repeat(2)

validation_data = convert_examples_to_tf_dataset(list(validation_InputExamples), tokenizer)
validation_data = validation_data.batch(32)
# Out:
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-5, epsilon=1e-08, clipnorm=1.0), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy('accuracy')])

model.fit(train_data, epochs=2, validation_data=validation_data)
# Out:
# Epoch 1/2
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7fa7066fa6c8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: <cyfunction Socket.send at 0x7fa723bda2a0> is not a module, class, method, function, traceback, frame, or code object
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7fa7066fa6c8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: <cyfunction Socket.send at 0x7fa723bda2a0> is not a module, class, method, function, traceback, frame, or code object
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#
# WARNING:tensorflow:AutoGraph could not transform <function wrap at 0x7fa7219b4c80> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function wrap at 0x7fa7219b4c80> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
#    1250/Unknown - 1126s 862ms/step - loss: 0.3542 - accuracy: 0.8382WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# 1250/1250 [==============================] - 1171s 898ms/step - loss: 0.3541 - accuracy: 0.8383 - val_loss: 0.3427 - val_accuracy: 0.8762
# Epoch 2/2
# 1250/1250 [==============================] - 1126s 901ms/step - loss: 0.1017 - accuracy: 0.9648 - val_loss: 0.4521 - val_accuracy: 0.8850

# %%
pred_sentences = ['This was an awesome movie. I watch it twice my time watching this beautiful movie if I have known it was this good',
                  'One of the worst movies of all time. I cannot believe I wasted two hours of my life for this movie']

# %%
tf_batch = tokenizer(pred_sentences, max_length=128, padding=True, truncation=True, return_tensors='tf')
tf_outputs = model(tf_batch)
tf_predictions = tf.nn.softmax(tf_outputs[0], axis=-1)
labels = ['Negative','Positive']
label = tf.argmax(tf_predictions, axis=1)
label = label.numpy()
for i in range(len(pred_sentences)):
  print(pred_sentences[i], ": \n", labels[label[i]])
# Out:
# This was an awesome movie. I watch it twice my time watching this beautiful movie if I have known it was this good :
#  Positive
# One of the worst movies of all time. I cannot believe I wasted two hours of my life for this movie :
#  Negative

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Colab Notebooks/twitter.csv"

import pandas as pd

data = pd.read_csv(path, header = None)
data.head()
# Out:
#                                 0  ...   9
# 0  Sun Feb 07 09:44:16 +0000 2021  ... NaN
# 1  Sun Feb 07 09:44:17 +0000 2021  ... NaN
# 2  Sun Feb 07 09:44:17 +0000 2021  ... NaN
# 3  Sun Feb 07 09:44:17 +0000 2021  ... NaN
# 4  Sun Feb 07 09:44:17 +0000 2021  ... NaN
#
# [5 rows x 10 columns]

# %%
data['tweets'] = data.iloc[:,1]
data['tweets']
# Out:
# 0      b"@SharksTennis @cbtaylor_7 @EamonnHolmes The ...
# 1      b'RT @Cit4Sol: Overwhelming public opinion bac...
# 2      b'RT @194303: 201610\n\n 209.3\n 179.8\n 95.0\...
# 3      b'RT @JaniceDean: New York releases data on CO...
# 4      b'RT @ddiddirere: please remember that all dig...
#                              ...
# 825    b'RT @tweeter4truth: Merck Challenges Safety &...
# 826    b'RT @chipro: So I wrote a 5400-word lecture n...
# 827    b'RT @SglParentRights: Really interesting data...
# 828    b'RT @robert_spalding: We are focused on schoo...
# 829    b'RT @MaleehaHashmey:    %95     \n\n    2019 ...
# Name: tweets, Length: 830, dtype: object

# %%
import re

def remove_features(text):   
    
    text = re.sub('(@)\w+', '', text)              # Removing @mentions
    text = re.sub('RT :', '', text)                # Removing RT 
    text = re.sub('https?://\S+', '', text)        # Removing hyperlink
    text = text.lower()                            # Lowercase everything
    text = re.sub(r'[^A-Za-z0-9 ]+', '', text)     # Keep alphanumeric and space only 
    
    return text

data['tweets'] = data['tweets'].apply(remove_features)
data['tweets']
# Out:
# 0      b   the latter is bad news its plenty big enou...
# 1      b overwhelming public opinion backs citizenshi...
# 2      b 201610nn 2093n 1798n 950n 580n580n 452n 435n...
# 3      b new york releases data on covid deaths at ea...
# 4      b please remember that all digital plays of od...
#                              ...
# 825    b merck challenges safety amp validity of all ...
# 826    b so i wrote a 5400word lecture note on the ba...
# 827    b really interesting data discussed at gm4wome...
# 828    b we are focused on school shootings why not t...
# 829                 b    95     nn    2019      8
# Name: tweets, Length: 830, dtype: object

# %%
data['tweets'] = data['tweets'].astype(str)
tweets = data['tweets'].tolist()
tweets
# Out:
# ['b   the latter is bad news its plenty big enough until it trades as safely amp ',
#  'b overwhelming public opinion backs citizenship4soldiers njoin harry redknapp amp lewis moody in backing automatic citize',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nn',
#  'b new york releases data on covid deaths at each nursing home ',
#  'b please remember that all digital plays of odd eye and rtu will contribute to end of year data which will be used for end o',
#  'b   i am sure they would be fascinating nnhowever more interesting and relev ',
#  'b data loss prevention strategies for longterm remote teams cybersecurity security  ',
#  'b geo   nn   nngeo data block is building a decentralized peertopeer big data sharing ecosyst',
#  'b   you are not intelligent but just quick to reply without fully grasping what i sa ',
#  'b  new airdrop kragxnn total reward up to 36 krx 18  6 krx 3 per referralnn start the airdrop bot ',
#  'b n27rnnhttps',
#  'b fox news has a pretty toxic track record in the us  the last thing britain needs is more media like this ',
#  'b  if you care about your data you really should dive into the ocean ',
#  'bfightfordemocracynherethevoiceofmyanmar',
#  'b have thrice worked on tools to set up local databases from production datannis there a company that automates this for al',
#  'b our analysis of nhse covid19 vaccine data found that white ppl arenngt 3xs as likely as mixed ethnicitiesngt 15xs as likely as',
#  'b these numbers reflect the latest data available as of jan 29 from the cdcs vaccine adverse event reporting system v',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'b data protection commissioner to regulate tiktok for all of europe  via ',
#  'b do care home staff know this do doctors know this ',
#  'bxsl  labs is a french project launched in the field of big datanand if you have any idea of data management i a ',
#  'b  have we got any data on sputnik',
#  'b   with a sample that size how old would you need the participants to be to ge ',
#  'b initial data indicate that astrazenecaoxford vaccine offers  limited practically nonexistent protection from coronav',
#  'bsecurity breach in ctd peshawar hq  nds mole gets ingress to classified data ig kp appoints a hacker to hack soci ',
#  'b sitepoint discloses data breach after stolen info used in attacks ',
#  'b please use the tagsnngot7  to 7 previous week 6 in the most mentioned kpop artists on twitter nnwhat is stopping you us',
#  'b lekker dan',
#  'b maricopa county refusing to turn it over is admitting to election fraud',
#  'b the uk vaccine project set out to deliver 146m doses by 15 feb its on course to get there by next saturday two days e',
#  'b hijabpaket data dan tiktok',
#  'bwe are probably the only company that is performing the full circle of design manufacturing composite electronic ',
#  'b save myanmar citizens d7nnwhatishappeninginmyanmarnmyanmarsnsfreedom',
#  'b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b naye nga dala omuntu atakulya lwaki aba akugulira data',
#  'b inm amp unicredit bank ireland were both run with with the high standards that chairman brian hillery of ',
#  'b    dapet data 99 darimana mas ngelakuin riset sendiri apa gimana dah wkwkwkwkw ga us',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b under 12 hour warning ndata collection for most shows ends in less than 12 hours along with the prevoting on ido',
#  'b       mira un smbolo hind el objeto ',
#  'b lumayan soalnya kan abis donlot app harus donlot data lagi',
#  'b 14051800 nhknews ',
#  'b the department of homeland security dhs is being sued by center for democracy amp technology cdt for failing to respond t',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'b please use the tagsnngot7  to 7 previous week 6 in the most mentioned kpop artists on twitter nnwhat is stopping you us',
#  'b hay que cerrarlo todo para acabar con el virus es cierto que si no acabamos con el virus primero no habr posibilida',
#  'b      ahhh we are at the gif stage but aga ',
#  'b  hapus mention yang terdapat data pelanggan ya terima kasih venti22',
#  'b nn',
#  'b language model experiment  take a vague forecasting question what will the future of robotics look like g',
#  'b no data to prove ur point  flash floods and avalanches are common in any snow covered mountainsnnthe ',
#  'b i think one of the flaws in some peoples view of data science is that you have to code everything excel is a great too',
#  'b let the world know nwhatishappeninginmyanmar nmyanmarsnsfree',
#  'bxsl  labs is a french project launched in the field of big datanand if you have any idea of data management i a ',
#  'b okay i cant keep buying a masks and losing them like i have a job i already have data stressing me ',
#  'b time for a precautionary principle approach nour data adds to growing call for actionnppe ventilation ',
#  'b',
#  'b 1 analysing nct hashmask data on nn11 of supply is on exchanges in the last days we see an increase of',
#  'b  karena mereka butuh data aktifitasmu supaya bisa ngasih ads yang tepatnntarget ads tepat  makin besar kemun',
#  'b lumena a yg pode soltar a data do solos',
#  'b do care home staff know this do doctors know this ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b  does he realise just how much electricity is needed to run the data centres and servers for h ',
#  'b i am today launching a small twitter initiative the campaign against nonsense about italy cani ill be tweeting data',
#  'b jan2021 heating data mean outdoor temp 32c typical night min 03c indoor mean 187c night 175c ',
#  'b how much is the average cost of a data breach in the healthcare industry',
#  'b businesses should begin assessing their data practices in order to meet the california privacy rights act requirements ht',
#  'b logistically speaking its impossible to deal with about 6b dead bodies over a 10y period without ',
#  'b indian drug regulator has denied emergency use authorisation to pfizers covid19 vaccine on the grounds that causality',
#  'b 2   n    n      nn2 weeks of mubeat awards votingncurious',
#  'bso if the average data was people in mid 30s how did they know the enhanced protection was due to the vaccine and ',
#  'bthe senior living digital marketing revolution needs call data  ',
#  'btadi pagi komplen jawabannya begininsore ini nanyain lagi gmn progressnya eh dijawab begini juga nnudah lama pe ',
#  'b kak dede terkait kode error 45 14 berkenan informasikan nomor layanan internet dan nomor hp nya v ',
#  'b i think one of the flaws in some peoples view of data science is that you have to code everything excel is a great too',
#  'b hangi lkenin hangi alar kullandn gsteren bu tabloyu hazrlarken srbistan ayn anda 3 farkl a kullanan tek lke old',
#  'b campaign against italy nonsense cainnnthis thread presents data that strongly reject claims that s problem has been a',
#  'b kjre deg som mener var er en god ide det er lov  snu du kan endre mening noen vil til og med forvente at det skjer nr fa',
#  'bno question as you say   if we look at data rather than opinions maintaining strict borders to uk ',
#  'b the interesting political question is why now after de croo knot and all that a new spin ',
#  'bsave myanmar citizensnrevolutioninburmanwevotednld',
#  'bin data standards news the groups primary goal is to create an open source data commons that will make it easy ',
#  'b  apunta data per quan  pegui el bot ',
#  'b  good funding news nwere very pleased to have won a  bid so that we can loan out laptops amp wifi unit',
#  'b thanks  for the opportunity super excited to partner with you to help brands use data to best serve their customers h',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'beast hempfield weather data r 0445 am temp 354f humidity 66 wind 36mph se gust 98 mph  se rain 000 barometer 29994',
#  'b the uk vaccine project set out to deliver 146m doses by 15 feb its on course to get there by next saturday two days e',
#  'bheres the first public version of raels polydrive his workinprogress mega drive synth instrument ',
#  'b all pension funds public and private have a fiduciary duty to hold bitcoin based on the data and fundamentals',
#  'b we fully reject military coup  save myanmar citizens d7 whatishappeninginmyanmar myanmarsnsfreedom',
#  'b if it will be slow it may be worth learning dma not that hard and can add a second core for e ',
#  'b ti ho seguita comunque si s posso seguire i profili essere seguiti puoi loggare  i film che ',
#  'bthis is excellent on the planning involved in getting the vaccination program running from development to issue ',
#  'b  is yet another paper with fantastic imaging arabidopsis roots from ',
#  'b 12netibnews  ',
#  'b   there are 44 countries in europe and 4 have stopped using it and will r ',
#  'b help retweetnnsame as last week this week secretnumber retweets are only 5k dear  please post more on twitt',
#  'b 2 n ',
#  'b    95     nn    2019      8       ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked',
#  'b 1 analysing nct hashmask data on nn11 of supply is on exchanges in the last days we see an increase of',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b childcare centres remaining open while schools have switched to remote learning for many pupils',
#  'b ministers use covid to take control over nhs england it will mean the slow dismantling of the nhs amp contracts being',
#  'borphnthe data from the disease in motion can be used for a multitude of different activities by potential custo ',
#  'b per reconsiderar les possibilitats de les utopies tecnolgiquesnnactualment els centres de dades consumeixen la mateix',
#  'b    95     nn    2019      8       ',
#  'b fox news has a pretty toxic track record in the us  the last thing britain needs is more media like this ',
#  'b  nnsnowmann',
#  'b ',
#  'bdangerous data part 1 why the heat an effectiveness bank hot topic  ',
#  'blearn it there are spying eyes everywhereand now they share a brain  via  tech digital data privacy',
#  'bvoi che avete messo in giro una falsa data per l ultima stagione di lcdp perch lo avete fatto',
#  'b     according to pfizers own research the immune system is compromised for a wee',
#  'b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely',
#  'b structured data extractionn n extract structured data across any siten validate against   google gu',
#  'b fox news has a pretty toxic track record in the us  the last thing britain needs is more media like this ',
#  'b check out the byline by our founder  on data regulation in 2021 in  this month nn',
#  'b benefits of being a datascientist professional via  abdsc ',
#  'bdata engineer  tech startup at  remote  apachespark',
#  'b ',
#  'b working to give people power in a new data economyn  founder of  nnhis mission resonate',
#  'baussies latest weather data 815 pm temp 185 humidity 57 wind 00 todays rain   00',
#  'b let our voices be heard let the truth br prevailed save myanmar citizens d7nwhatishappeninginmyanmarnmyanmarsnsfreedom',
#  'b   have we got any data on sputnik',
#  'bweather data r 0445 am 231 67 pct 02 wnw',
#  'b 2   n    n      nn2 weeks of mubeat awards votingncurious',
#  'b what gets you going what gets you up in the morning what kind of change do you want to see learn how data science a',
#  'b the physicals for all biometric database purported to be a health initiative by china has also been proven part of mass',
#  'b   n  microsoft is investing aggressively in its azure cloud computing service particularly in',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'brt  embedded machine learning unlocks the potential of the currently unused enterprise data and enables ',
#  'b   ',
#  'b sore kak mau tanya untuk update data diri di bank syariah itu bagaimana ya caranya karena sebel ',
#  'b artificial intelligence can do so muchninfographic by    nndata datascience ai artificia',
#  'b programming coding programmer javascript html machinelearning css 100daysofcode bigdata iot artificialintelli',
#  'b naver 210207nnbtsv aka prince of the continent ranked 1 among all korean celebs on aimans a chinese big data analys',
#  'b nnn1840577nn',
#  'bshout out to the best payment app n',
#  'b interesting hospitalization data for children in england over the past few months nnsignificant change in the 05 yo categ',
#  'b   do not go to tims website homefirstsuperseconddotcom nndo not leave your details therennti',
#  'b semoga menang yaallah bsk ada zoom meeting uangnya mau beli paket data',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'bkindly make the data public of the number of farmers death at protest site opportunistic congress are increasing t ',
#  'b bisp data cleaning under ehsaas governance framework in 2019bisp exited 820165 individuals from its beneficiaries li',
#  'b bisp data cleaning under ehsaas governance framework in 2019bisp exited 820165 individuals from its beneficiaries li',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b   infatti perci data la mia non tenera et avrei suggerito a meloni ',
#  'b absolute proof summaryn2hr runtimenall 3 navarro repts evidence revisitednstarting on nov 1st white hat us h',
#  'b all the terrorists who stormed the capitol can be tracked down using their location data and i expect them all to be ar',
#  'b ppl selling databases of phone numbers to bizs in kenya ampbizs who buy the databases then send mass texts to subjects who',
#  'bthe astrazenecca vaccine to be treated like flu vaccine annual updating might be required to cover variantsndelay ',
#  'b nn ',
#  'b 1 analysing nct hashmask data on nn11 of supply is on exchanges in the last days we see an increase of',
#  'b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k',
#  'bdata 0945 pressure 10023 hpa temp 06oc hum 96pct wind 65 mph nnw rain today   51 mm month 368 mm snowfall today 00 snow depth0',
#  'b subsidies and public spending need to be prioritised  evidence based that in how much aggregate soci ',
#  'bi can find no concrete data on how much lighter zephyr actually is disappointing',
#  'b same problem here the network here in gadau is very bad even for calls talkless of data',
#  'b third and last day well track shoseki one piece holds its position phantom seer even manages to climb 1 place in the rank',
#  'banother great start to the day dont we need someone explaining the practicalities here from gvmt if we need to ',
#  'b pm imran khans govt has been making claims about its economic performance based on the improvement on current account and',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'bnn the movienn',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'bsch tmn2 mau nanya dong klo validasi data ltmpt itu alamat yg dipakai alamat tinggal saat ini atau alamat sesuai ',
#  'b the ccp and affiliated authorities are using artificial intelligence to scan massive amounts of data on communication apps fre',
#  'b   usb data    ',
#  'bpart of the plan legitimate cull of elderly people',
#  'b and there is 1 psychiatrist for each 85000 lebanese mentalhealthawareness psychiatry ',
#  'b yes  is the most dangerous person in nhes deaf to data deaf to real stories deaf to hundreds of m',
#  'b check out the byline by our founder  on data regulation in 2021 in  this month nn',
#  'b  you can use alot of the data on the covid tracker app to analyse this we seem to be on a plateau now',
#  'b nnn1n2n3',
#  'b these numbers reflect the latest data available as of jan 29 from the cdcs vaccine adverse event reporting system v',
#  'b my point is this when it comes to how the world has dealt with the coronavirus you would have to say we chose the chi',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b   january 19 was because of a data lag notice no vaccinations were reported in the previous days',
#  'b the uk vaccine project set out to deliver 146m doses by 15 feb its on course to get there by next saturday two days e',
#  'ball of nsw most of tas some of qld and little parts of sa and vic are covered ill analyse the lidar data and te ',
#  'b data giveaway by  nfollow him to benefit this sunday morningnnmake sure you rt',
#  'b this is a really helpful matrix for any powerquery user either in excel powerbi ssas or dataflowsnn ',
#  'b nnnnnnnnnn12800nn nn nniodata exldh241dbnn',
#  'bvous pouvez rt a svp',
#  'b any person who claims to be an expert economist who doesnt have an advanced knowledge of math shouldnt b ',
#  'b its no secret that we  lakehouse architecture but when it solves so many common issues with data warehouses amp improves',
#  'b 14051800 nhknews ',
#  'b no mbamalgalicia estreamos a seccin big data analytics na que  e  do  nos trouxer',
#  'b create your free account big data fundamentals with pyspark learn the fundamentals of working with big data with pyspark',
#  'b2 permeabilitygoogle mapslive traffic',
#  'b   ',
#  'b settings  storage  apps  clear data and clear cache',
#  'b an out of the box campaign with market potential supported by raw data could lure investors',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'bchina launches public data platform to trackpollution ',
#  'b  and downing street claims it doesnt recognise the traders data and falsely claims tra ',
#  'b the movienn',
#  'b when discovered seianti hanunia tlesnasas skeleton was still inside her sarcophagus the british museum has therefore been ab',
#  'b the movie  johnnys webnnsnowmannew ',
#  'b level up your data science vocabulary affinity matrix  machinelearning affinitymatrix',
#  'bnn',
#  'b  kpop artists next big sound social metrics weekly tallynndata collected from january 23 to 29 ',
#  'b the objective data disagreesnn2 recessions record unemployment record insecurity amp record national disunity',
#  'bsave myanmar citizens d7nnwhatishappeninginmyanmarnnwevotednld nmyanmar people ag',
#  'b im sure tils and sng will have similar results on patients with moderatesevere illness 100 of p ',
#  'b they stormed the capitol their apps tracked themntimes opinion was able to identify individuals from a trove of leaked s',
#  'b 3 the preliminary finding from the  vaccine trial placebo group based on a data set with limitations stirred debate',
#  'b ministers use covid to take control over nhs england it will mean the slow dismantling of the nhs amp contracts being',
#  'b airtimedata giveaway nn follow n n rt this tweetnnlets goooo',
#  'b    dapet data 99 darimana mas ngelakuin riset sendiri apa gimana dah wkwkwkwkw ga us',
#  'b check out the byline by our founder  on data regulation in 2021 in  this month nn',
#  'b  the movien27 1600nnnnn n  web 300n',
#  'b',
#  'b the interesting political question is why now after de croo knot and all that a new spin ',
#  'b  not that theyve said but thats why id be concerned its the reason why you anonym ',
#  'b new book out on using tidyverse tools for data science written with   and  ',
#  'b',
#  'b great these last few weeks to have worked on a number of projects including on nps housing arrearsplanned maint and da',
#  'bproses vaksinasi di indonesia yang berjalan sangat lamban adalah contoh nyata dari kombinasi buruknya manajemen da ',
#  'b price data is daily live',
#  'b campaign against italy nonsense cainnnthis thread presents data that strongly reject claims that s problem has been a',
#  'b uploads cvngt thank you now please input the same data broken up into these 36 form fields',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'b 2   n    n      nn2 weeks of mubeat awards votingncurious',
#  'b no mbamalgalicia estreamos a seccin big data analytics na que  e  do  nos trouxer',
#  'b uploads cvngt thank you now please input the same data broken up into these 36 form fields',
#  'bchosun online    nn ',
#  'b 4 dr fauci the data really are quite suggestive the level of immunity that you get from natural infection  either the',
#  'bnigerians stop playing policies with the economy you will keep getting porter if you do say the truth so the prob ',
#  'b kalau pake data seluller ganti pake wifi sebaliknya aku jga gitu tdi pake data kuganti pake wifi bisa ',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'b zeer zorgwekkende berichten uit engeland over ziekenhuisopnames en mis onder kinderen zie ook de trend nde scholenope',
#  'b i asked my friend to buy me data she legit asked me nze akuzina nnmaze okwesabyasabya',
#  'b ',
#  'besse aqui  meu nico tweet sobre o bbb sem data de validade',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'b  ',
#  'b please for the love of svt rt  tweets  the differences between rts and likes are waaaay too big and t',
#  'b i recently had an energy provider change imposed and i am not a fan of the data shown on their webs ',
#  'bci provo a modo mio spiegare almeno 1 vantaggio pratico di avere un phd nngt  ',
#  'b como sigamos llamando inteligencia artificial machine learning y big data a todo lo que no sale de un spss random for',
#  'bjust watched attack on titans with my data plan cause i forgot to turn on the damn wifi ',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'bdoes that mean other countries have more covid19  vaccine data  marr',
#  'b mike yeadon former vp and chief scientist at pfizer one of the most important information sources has been cancelled',
#  'b      nn                       ',
#  'b  hopefully thats kujata  although yoship just announced that they are adding data centre visit ',
#  'b   i think recent events over the last quarter have also promoted you ',
#  'b shocking hospitalization data for children in england over the past few months nnsignificant change in the 05 agegro',
#  'b',
#  'b science data and tech are coming together like never before to deliver breakthroughs that will transform human health o',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b  the movien27 1600nnnnn n  web 300n',
#  'b you bring the clients ileads provides the best real estate data and the best mortgage and insurance leadsnyou solve your c',
#  'b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely',
#  'b    per aix no sha deixat canviar la data perqu la gent no ',
#  'bfake environmental activists activated if they blame dams and roads tell them downstream lutyens is safe because ',
#  'b   again in ga and there was court cases still in the courts where rep states had ',
#  'b mike yeadon former vp and chief scientist at pfizer one of the most important information sources has been cancelled',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b jya muri settingsgtappsgttwittergtstoragegtclear datanubundi uyifungure uhindure password',
#  'bchina is launching a public data platform to name and shame polluters ',
#  'b  from the creator a link between nodes means that both accounts were retweeted mu ',
#  'b    95     nn    2019      8       ',
#  'b  yes but the question is ndo you trust the use of the data',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'b ekonom senior yang juga mantan menko perekonomian kwik kian gie beradu data dan argumen soal utang indonesia dengan staf kh',
#  'b science data and tech are coming together like never before to deliver breakthroughs that will transform human health o',
#  'b omars campaign was by far its biggest moneymakerdolingout 146 checks for 29 million or 78 percent of the firms',
#  'b point nya senang je berhenti la trend false advertisement demi nak dapatkan data orang jijik gila perangai',
#  'b methane ch potent greenhouse gas reached a preliminary record high value in october 2020 18909 ppb note there is a sea',
#  'b   touche nope didnt compare the people i asked if the database was going to ',
#  'b  ',
#  'bnew feb sec filing by legend s  aims for 15 aggregate investment in bitcoin exposure ',
#  'b new guidancennensuring we do no harm while maximizing the benefits of data requires collective action that extends across',
#  'b itna kum  itne ki toh main apne friends ko gifts de deti hoon  kitne saste hain yeh sab yaar hahahaha biggest f',
#  'b trump it wasnt menscience pretty sure it was you',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'b the movienn',
#  'b  we agree darren and we will be working with the local highways authority to undertake ',
#  'bsave myanmar citizens d7nwhatishappeninginmyanmarnmyanmarsnsfreedom',
#  'b start learning for free hierarchical and recursive queries in sql server learn how to write recursive queries and query hier',
#  'b 2 juta data wabah disumputin terus gegayaan mau digitalisasi sertipikat tanah dumb evil is dumb evil ',
#  'b its either data capture exhortations for money or porn or sometimes a combo its across pretty much ',
#  'b12 3860000n',
#  'b uploads cvngt thank you now please input the same data broken up into these 36 form fields',
#  'b create your free account multivariate probability distributions in r learn to analyze plot and model multivariate data h',
#  'bcustomer service in dubai united arab emirates service data customer entry product shift ',
#  'b few days ago i accompanied a friend for verification and data capturing as a duly registered member of one of the leading',
#  'b rent arrears in the socialhousing sector have exceeded 1bn during the covid19 pandemic data has revealed ',
#  'b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit',
#  'bvenezuela jails officials for giving us oil datann ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b the first major campaign launched by the  team is underwaynncomplete a list of micro tasks to enable us to',
#  'b what is  motive in pitting  vs  nthis is evilnboth r digital partners to get ahe',
#  'b pinterest seo 12 tips to optimize your pins for searchnn nadtech advertising datamining ap',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b fyi ive relinked my mobile number having to use a spare phone because it would not allow me to buy ',
#  'b uploads cvngt thank you now please input the same data broken up into these 36 form fields',
#  'b a swiss tech company believes its found a security weakness that could jeopardize the confidentiality of the worlds interne',
#  'b should be repeatedndominion denies anybody this happened but is also fighting tooth amp nail to keep anyone from investig',
#  'b  nn 19',
#  'b to us who will not receive even 1gh biscuitmay god provide us with money to buy dataso we can view status ',
#  'b                   ',
#  'b   under the guise of other religions ethnic terrorists have formulated an idea t ',
#  'b  sir pls look into the matter as per data published on newspaper    ',
#  'b nnn1840577nn',
#  'b if all those online certificates in data analysisartificial intelligence amp machine learning which people never fail to',
#  'bhau non ha mai sconfitto hala glielha data vinta semplicemente perch hau  suo nipote e gli fa pena',
#  'b my new hobby is taking graphs of economic data over time and indicating the year that ronald reagan was inaugurated in ca',
#  'bupdate data uji pcr covid19 di indonesia per tanggal 7 februari 2021 pukul 1200 wib bersamalawancovid19 ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b como sigamos llamando inteligencia artificial machine learning y big data a todo lo que no sale de un spss random for',
#  'b thisnthingnannoysnmynsoul',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b venezuela jails officials for giving us oil datann ',
#  'bbut thats just reported ones much like abused women numbers in reality are so much higher ',
#  'b if you believe this sponsored report that uses irish data from 1922 youll believe anything ev ',
#  'b using a trove of leaked smartphone location data  and  identified some of the capitol rioters',
#  'b   mungkin saya yang kelewat rajin baca sih sampe data beginian saja saya dapet hehe ',
#  'b     see his profile hes been publishing timeline data',
#  'b our analysis of nhse covid19 vaccine data found that white ppl arenngt 3xs as likely as mixed ethnicitiesngt 15xs as likely as',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'b pleased that data from our  diagnostics and sequencing team could contribute to these analyses about spread',
#  'b    95     nn    2019      8       ',
#  'bthese viruses can be fascinatingly beautiful ',
#  'b update as crowds gather for a second day of anticoup protests in myanmar realtime network data show the country remains',
#  'b marital rape is punishablenbut how many have been punished for nikah halalando you have any data for that',
#  'bas an interviewer judging a candidate on this aspect is similar to judging a content creator who is comfortable amp f ',
#  'b campaign against italy nonsense cainnnthis thread presents data that strongly reject claims that s problem has been a',
#  'b7 best tools for structured data schema testing amp execution via   freelancers ',
#  'b we are seeking 2 postdocs to join our team 1 experimental biology examining therapeutic benefits of correcting rare',
#  'b if your account was disabled you can download and save your data learn more about this here ',
#  'b really good article with excellent interpretation of the published data by ni think we know the answer is a res',
#  'bwhat does this mean in areas with high proportion of people of colour it is impossible to understand how covid19 ',
#  'bkebakaran menghanguskan dua unit komputer dan cpu yang berisikan data penjualan sepeda motor dan suratsurat kendar ',
#  'bpfizerbiontech new data on vaccine effectiveness against uk strain   update from pfizer ',
#  'b if you were a eu citizen who stormed the united states capitol on january 6th you might be eligible for compensation from p',
#  'bmy isp is down again mobile data is still working for now even if they cut off everything again know that we are ',
#  'b stuck in twitter amp nationalist media echochambers rw chowkidars refuse to see the writing on the wall what started as',
#  'b absolute proof summaryn2hr runtimenall 3 navarro repts evidence revisitednstarting on nov 1st white hat us h',
#  'b bisp data cleaning under ehsaas governance framework in 2019bisp exited 820165 individuals from its beneficiaries li',
#  'b these viruses can be fascinatingly beautiful  ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b yesterday we heard from the government in our covid19 data inquiry the   ministers delegated',
#  'b  kpop artists next big sound social metrics weekly tallynndata collected from january 23 to 29 ',
#  'b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit',
#  'b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely',
#  'b what is  motive in pitting  vs  nthis is evilnboth r digital partners to get ahe',
#  'b finder an automated software package to annotate eukaryotic genes from rnaseq data and associated protein sequences',
#  'b now 3 vaccines have been shown to have diminished efficacy against b1351 south african all prevent death and hospitaliz',
#  'b in chicago 80 percent of gunviolence victims in 2020 were black according to the latest data in new york city 71perc',
#  'b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k',
#  'b  where to lodge complaint against digital lending app  contact list we have proof they are using user con',
#  'b the movie  johnnys webnnsnowman  ',
#  'b',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'bdata from my cellar thanks to electric imp discover kit temp 1421  humid 13867  pressure 97225',
#  'bwhile im optimistic about us vaccination progressit is still going to take them months to clamp down on some of t ',
#  'b  nn 19',
#  'bstart learning for free data visualization in r this course provides a comprehensive introduction to working with ',
#  'b venezuela jails officials for giving us oil datann ',
#  'b the interesting political question is why now after de croo knot and all that a new spin ',
#  'b powerbi blogpost ',
#  'b you can delete messages chats call history and groups you created at any time deleted items completely disappear for all p',
#  'bbitwarsoft bitwar data recovery  data recovery software for windowsmac ',
#  'b i am today launching a small twitter initiative the campaign against nonsense about italy cani ill be tweeting data',
#  'b uop for surenn provides a base for the music industry that everyone can benefit from  ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'bthis is the most inefficient big data tool ever i dont even see it breaking into the tech space',
#  'b a must watch for allworthy of your time data and attention     https',
#  'b vir a tool to solve intrasample variability in the prediction of viral integration sites using whole genome sequencing',
#  'b absolute proof summaryn2hr runtimenall 3 navarro repts evidence revisitednstarting on nov 1st white hat us h',
#  'b   i like the idea in the article of thinking in terms of cold and warm data ',
#  'b jste zodpovdni a vy speciln jako lka za zpochybovn opaten vldy s dopadem na veejnostkterou t ',
#  'b workers who have decied to stay put celebrated the upcoming spring festival together at the construction site of the huawei clou',
#  'b ',
#  'b   so apparently asking for my number was just for data base pathetic customer service',
#  'b ',
#  'b  guess what i have missednnantother databreach sitepoint handed over user data to unknown 3rd partynn https',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b fox news has a pretty toxic track record in the us  the last thing britain needs is more media like this ',
#  'b having received substantial public funding we encourage all manufacturers to share their data and technologynnwho chief h',
#  'bbeberd off his fking data',
#  'b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k',
#  'b data detox kit  zure pribatutasun segurtasun eta ongizate digitala egoki iruditzen zaizun moduan kontr',
#  'b douluoday2nhow can ixfx watch and increase popularity for douluo continentnn1 watch online on  app watching on this',
#  'b most important bit of evidence weve seen so farnnticktock',
#  'b you bring the clients ileads provides the best real estate data and the best mortgage and insurance leadsnyou solve your c',
#  'btay tawan ti devo ricordare la tua data di nascita',
#  'bdata26nnnn1n242nn2n5 ',
#  'b all  who authorized are stupidnndo you think you are talking to childrennnthey warned fg fbn so why hav',
#  'b statistics the science prove children resilient the government amp  had zero reasons to close schools ',
#  'b   do not go to tims website homefirstsuperseconddotcom nndo not leave your details therennti',
#  'b nn',
#  'b do care home staff know this do doctors know this',
#  'b social media research  present socialmedia network analysis n reduced academic priceninfo  http',
#  'b  i find the app more than cumbersome sorry  you can only buy the coins in a roundabout way ',
#  'bwhatshappeninginmyanmar fightfordemocracy',
#  'bheden tracken wij kapitoolbestormers morgen zijt gij aan de beurtnthey stormed the capitol their apps tracked t ',
#  'b   do not go to tims website homefirstsuperseconddotcom nndo not leave your details therennti',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'b    n   because its one hell of a ride nan in depth analysis of official ons',
#  'b my new hobby is taking graphs of economic data over time and indicating the year that ronald reagan was inaugurated in ca',
#  'b to us who will not receive even 1gh biscuitmay god provide us with money to buy dataso we can view status ',
#  'b should be repeatedndominion denies anybody this happened but is also fighting tooth amp nail to keep anyone from investig',
#  'b nnn',
#  'bthe owner of this account data is probably too obvious to even bother mentioning ',
#  'b  statistics the science prove children resilient the government amp  had zero reasons to close schools to be',
#  'b british drugmaker astrazeneca said on saturday its vaccine developed with the university of oxford appeared to offer only li',
#  'b nn',
#  'b i read the paper referenced in this article and its a subjective study that correlates positive mood ',
#  'bstumbling across a compendium of data that ive always dreamed of ndefinitely going to be digging into their met ',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'b 1 so europe has its own adverse events reporting system for drugs and vaccines called eudra it now has data for the co',
#  'b et aprs on ose dire quon est encore dans une dmocratie coronafolie dictaturesanitaire',
#  'b tamb li podem donar la volta i dir que els indepes que anirn a votar en unel eleccions amb data impo ',
#  'b sebuah utas nthread  by   ncc ',
#  'bworkers collect a handheld scanner that records their every move for the next 10 hours feeding productivity data ',
#  'bsabe magpatulong daw kay maam kim pag may hindi alam sa treatment of data kaso mo hindi ko naman alam kung anon ',
#  'b   do not go to tims website homefirstsuperseconddotcom nndo not leave your details therennti',
#  'b how can ixfx watch and increase popularity for ndouluocontinentnn1 watch online on  app watching on this app is no',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely',
#  'bmantep tiap hari dicicil naik 01',
#  'btelenor myanmar has restored cell service after the military shut it down  reminder from',
#  'b nnn1n2n3',
#  'b quick explainer on using an esim in myanmar with roaming data nn nmyanmar',
#  'b language model experiment  take a vague forecasting question what will the future of robotics look like g',
#  'b venezuela jails officials for giving us oil datann ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'bno more silencennwhatshappeninginmyanmarnfightfordemocracy',
#  'b    you understand we left a month ago right i doubt anyone ',
#  'b i want to draw attention to a new page in documentation that was published with little fanfare  did a great',
#  'bwe should conduct our elections with that same integrity most in dc dont have integrity to begin with just say ',
#  'bdata viitoare cand m mai deschid n faa cuiva va fi la autopsie ',
#  'b selamat sore railmin bantu cek silakan diinformasikan data yang dikirim via dm ya trims',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b 800g test from keysight technologies validates nextgen data centres keysight technologies has released ',
#  'blasie aime trop luffy et cest normal',
#  'bon the comments of president  professor sarah gilbert tells  that we will have efficacy ',
#  'b part 3 of decodeme team member annas transcript of decembers winter webinar is now available to read on her blognngo',
#  'bdata pcrpost ',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'b   because the data coming out of china can be relied upon they can be trus ',
#  'b  big data es cualquier cosa que convierta una query sql en grficas de lneas o de barras e ',
#  'b   wawww 99  data dari mana mas  ',
#  'b you bring the clients ileads provides the best real estate data and the best mortgage and insurance leadsnyou solve your c',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b this is quite important but remember everyone all characters have different dash gt shield data corrin and sheik are th',
#  'b data design should clarify and not necessarily simplify   ',
#  'b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely',
#  'b    dapet data 99 darimana mas ngelakuin riset sendiri apa gimana dah wkwkwkwkw ga us',
#  'b added to the pile of ivermectin data for covid marked statistical significance of becoming covid pcr negative sooner',
#  'b should be repeatedndominion denies anybody this happened but is also fighting tooth amp nail to keep anyone from investig',
#  'b while in the military i pointed this out as a flaw in personnel statistics that required peercomp ',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b our cdc followed the ccps lead why didnt they follow taiwans recommendations why didnt the who listen to taiwan',
#  'b    again try to understand issues before projecting your jaudiced ',
#  'b in december ethiopias information network security agency claimed that the tplf was producing over 20000 tweets containin',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'bwho knows where to find data for daily trades volume for crypto currencies',
#  'ba briga desse dia',
#  'b the objective data disagreesnn2 recessions record unemployment record insecurity amp record national disunity',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'bnice to see  organising a pretty cool training event on analysing socialmedia data for academic res ',
#  'bdynamic service chaining in a data center with nexus infrastructure  ',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b210207   nn txtn   nn  nn  data',
#  'b excited to bring my workshops online join me to discuss dataviz sketch some data stories and improve your infogr',
#  'bthey took our freedom of speech  ',
#  'b artificial intelligence can do so muchninfographic by    nndata datascience ai artificia',
#  'b how future jabs might look like why eus attacks on astrazeneca amp the restrikting of their jab to under 65 year old a',
#  'b my new hobby is taking graphs of economic data over time and indicating the year that ronald reagan was inaugurated in ca',
#  'b 5 essentials to build a data strategy  via  nnai machinelearning datascience iot flutt',
#  'b please use the tagsnngot7  to 7 previous week 6 in the most mentioned kpop artists on twitter nnwhat is stopping you us',
#  'b ',
#  'b ive used 5568 gb data since 10 iannnsidnaaz mvs in 100m club',
#  'bnnnn ndata  n n n  nnn ',
#  'bkalian data jajan kaya begini kagak sampe di buat sheet per go  ada yang umum buat yang co di luar go  padahal ',
#  'bnnnnnnn n ndata  n nnn  2chn ',
#  'b 12wksn nn12wksnamp',
#  'bthey went live but im only using my data ',
#  'b how future jabs might look like why eus attacks on astrazeneca amp the restrikting of their jab to under 65 year old a',
#  'b 1 bahas tipis2 pertumbuhan ekonomi ri 2020 ya bbrp hari yl bps merilis data pertumbekonomi yg menunjukkan perekonomi',
#  'b coronavirusndatanle passeport vaccinal pour aller au restaurant au cinma par exemple sera un qr code sur le tlphon',
#  'b interesting hospitalization data for children in england over the past few months nnsignificant change in the 05 yo categ',
#  'bgetting data here is an extreme sport and im so frustrated rn',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b please for the love of svt rt  tweets  the differences between rts and likes are waaaay too big and t',
#  'b baik kak hanifan maaf ya mengenai kendala sinyal tidak stabil jika sudah melakukan saran yang dibe ',
#  'b como sigamos llamando inteligencia artificial machine learning y big data a todo lo que no sale de un spss random for',
#  'b sample ito ng mga fake newsnnme masabe lang itong grupo ni sec bunganga tugadennsa caption at laman nito two years oper',
#  'b bugs 6pm kst oddeye dropped to 95 on the bugs realtime chartnn dont give up just yet somnies nndata collection f',
#  'b truly worryingnnif we return without significant new mitigations this trend is what well return to nnkids filling ou',
#  'bsarah gilbert on marr defending the oxford vaccine as expected but failed to admit its not effective against the ',
#  'b the data is manipulatednare you going to allow yourself to be manipulatedn',
#  'b uploads cvngt thank you now please input the same data broken up into these 36 form fields',
#  'busa uber antisocialentreprise proesclavagiste   et  ont mis 205mde pour le prop 22 de calif ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b top 15 free datascience machinelearning amp statistics books for 2021 by  nn',
#  'b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b statistics the science prove children resilient the government amp  had zero reasons to close schools ',
#  'b the website i used to get all this data is  actually offers a wa',
#  'b top 15 free datascience machinelearning amp statistics books for 2021 by  nn',
#  'b english link is here must read id say',
#  'b im laughing so hard right now ',
#  'b how future jabs might look like why eus attacks on astrazeneca amp the restrikting of their jab to under 65 year old a',
#  'breducing the need for complex processing in the cloud or at the edge the less data sent to the cloud for processi ',
#  'b we should conduct our elections with that same integrity most in dc dont have integrity to begin with just sayin',
#  'b',
#  'b 2   n    n      nn2 weeks of mubeat awards votingncurious',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b top 15 free datascience machinelearning amp statistics books for 2021 by  nn',
#  'b top 15 free datascience machinelearning amp statistics books for 2021 by  nn',
#  'b no mbamalgalicia estreamos a seccin big data analytics na que  e  do  nos trouxer',
#  'b cdc data supports the reopening of schools but the wh refuses to move in that direction yet  what do you think is goi',
# ...
#  'bcheck out my podcast the catholic faith podcast on   nnhey friends please click t ',
#  'b hay que cerrarlo todo para acabar con el virus es cierto que si no acabamos con el virus primero no habr posibilida',
#  'bmoomoos please retweet as much as you can it helps to share mamamoo news ',
#  'b    beneerrrr pernah kek gini bahasnya fokus ke a eh kemana mana b ke z susah emg kalo',
#  'b  2020      chief data officer      nn  ',
#  'b a new banner for self sovereign id amp data to launch  to the next phase this year nnont ong https',
#  'b deutschland testet so wenig wie sonst nur sdosteuropanabsolut peinlich dafr gibt es keine valide ausredenes is',
#  'b  statistics the science prove children resilient the government amp  had zero reasons to close schools to be',
#  'b hold her accountable for the things she and others says  reporters editors politicians she attacks compa ',
#  'b 2 n ',
#  'b 42 mamamoo nnwe certainly need to improve our social engagements  rt more amp please use the tags for all positive postsnn',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b el nyt ha trazado la localizacin de miles de asaltantes del capitolio desde dentro del edificio a sus casas cmo su mvil',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'b government is releasing gst compensation to respective states promptly every monday  i personally take note of the data as',
#  'bare you going to reply my dm or not',
#  'b once peeped this thanks to  app i was actually tracking my data usage for the month ndakuona tinder as one',
#  'b 3  n187164121117n937269n54503030n27 n',
#  'b visual proof they went to the capitol for him he asked them to go he asked them to stop what was going on they tried and',
#  'b this is indeed shaping up to be a key year for dataregulation as proclaimed  in the  article ',
#  'btodava no me puedo creer que vayan a meter data center travel en el ff14 podre jugar con amigos de europa o inclu ',
#  'b screams in data',
#  'b hearthevoiceofmyanmar helpmyanmar silencedvoicesinmyanmar',
#  'b top 15 free datascience machinelearning amp statistics books for 2021 by  nn',
#  'bfor me as a scientist this is beyond disgrace faking scientific data to justify lockdown  people are sufferin ',
#  'b unfortunately most people dont understand the importance and legal aspects of information governance ',
#  'b 2   n    n      nn2 weeks of mubeat awards votingncurious',
#  'b ekonom senior yang juga mantan menko perekonomian kwik kian gie beradu data dan argumen soal utang indonesia dengan stafsus',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b  sadly jane doesnt understand the data',
#  'b pakistani armysnpakistan is at 33 with 139m views in last weeks datan30 jan5th febnour goal for this week is 16m',
#  'b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit',
#  'b 4 1n8151093n816261745283304n7983n https',
#  'b my prediction was correctsweden just surpassed the peak they had in aprilnndue to reporting delays its only today that f',
#  'b i was honored to help launch  global report on traffickinginpersons all governmentseveryone else must read for cru',
#  'b opinions is one thing heres the facts using fbref data for the current season there is less stoppag ',
#  'b all  who authorized are stupidnndo you think you are talking to childrennnthey warned fg fbn so why hav',
#  'bla gira con los pibes tienen mucha data',
#  'b  we did not have finegrained data on type of mask surgical vs ffp2 or use of oth ',
#  'b breaking the first realworld data from the uk vaccine rollout shows promising evidence that justifies the delayed s',
#  'bits strange how despite all the investment and advances in data science and computation we still cant predict th ',
#  'b pan  mohli bychom vidt et za natoen propaganho videa o cench respirtor kter jste zveejnila a',
#  'b i gotta head out tocause i mean i obviously want to hear how her heart is doing but yall take care ill pop in now',
#  'b precisa baixar o preo da gasolina e lcool tambm aqui em salvador na data de ontem 0602 fizera ',
#  'b maricopa county refusing to turn it over is admitting to election fraud',
#  'bhm hahaha',
#  'b helix technologies inc hlix cannabis fintech medicalmarijuana medical data storage hipa stocks billio',
#  'bun espai per compartir i seguir apostant per una metodologia que transforma l  educaci i el mn ',
#  'b a partir de lundi le monde rvle openlux une dataenqute dun genre nouveau sur le luxembourg en collaboration avec ',
#  'buseful for anyone looking at pupil premium and policies around disadvantaged pupils what might this data suggest ',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'bcurrently overcast and 17 f at cleveland hopkins international airport oh winds are southwest at 81 mph 7 kt ',
#  'b helix technologies inc hlix cannabis fintech medicalmarijuana medical data storage hipa stocks billio',
#  'bapplynow la scuola superiore santanna promuove la seasonalschool the responsible data societynnel video i temi ',
#  'b its strange how despite all the investment and advances in data science and computation we still cant predict the weather ac',
#  'b really take a moment to ponder thisnthe maricopa board of electors are willing to go to jail by ignoring subpoenas and h',
#  'bmurdering hornets step aside',
#  'b worth a read  ',
#  'bomo this is the reality of thousands of nigerians unable to properly feed this man doesnt think of data or acce ',
#  'bhere is a prime example of fake climate science deliberately altering data to suit their real agendanits fraud',
#  'b hai mohon maaf kak aditya sistem kami sedang dalam proses pembaharuan data keluhan kakak tetap dicata ',
#  'b which countries are most exposed to floods and where does floodrisk and poverty intersect  check out these new interactiv',
#  'b red skies saharan dust makes it to switzerland nsince our operational snow models do not yet account for these type of',
#  'b  hallo you can read it here campaign against italy nonsense cain this thread presents data that stron',
#  'b  settings  installed apps click on twitter  clear cache and datanrahul vaidya for the win',
#  'b emm mai ne abi tk mobile data use b nahi kiya hai wallah nmai rusith hu mje nahi chahiye',
#  'b since the day wey i sabi transfer buy data n airtime from my bank my life no balance again ',
#  'b thread da leggere con attenzione conservare e sbattere in faccia  allidiota di turno che ciancia di compiti a casa che',
#  'b 14051800 nhknews ',
#  'b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k',
#  'b     ',
#  'b breaking the first realworld data from the uk vaccine rollout shows promising evidence that justifies the delayed s',
#  'b if you got picked njust dm me details to collect your winningnegnif you want data 1gb  081 mtn 1gb n500 airtime',
#  'b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit',
#  'bcciv',
#  'b key data has been deleted from govts debt report indicators on total public debt as  of total revenue debt service co',
#  'b  i bought wifi private bundles for 8gig and hourly for 1gig via ecocash but i haven ',
#  'b  i couldnt agree more it certainly doesnt serve the masses as well as it could rig ',
#  'b mapping lightning strokes ',
#  'b top 15 free datascience machinelearning amp statistics books for 2021 by  nn',
#  'b52 of the companies had accelerated their adoption of ai due to the pandemic and nearly 25 of them had fully emb ',
#  'b nn',
#  'b  we did not have finegrained data on type of mask surgical vs ffp2 or use of oth ',
#  'b here is a prime example of fake climate science deliberately altering data to suit their real agendanits fraud http',
#  'b this is not good news 2026 pts in sa  hiv neg young median 31 yrs az vax not protective against mild mod infection no',
#  'b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya',
#  'b hold onwaitlast monday dr anthony fauci said that wearing two masks likely made it safer but now this week dr',
#  'bthe absence of data on the efficacy of astrazeneca vaccine in over 65 renders those eu countries that have refused ',
#  'bwashington state introduces new data privacy bill the peoples privacy actn  ',
#  'b    pode mandar print qual a data da edio',
#  'b verox status report 3 is now outnnmajor updatesn we have hired another 3 ai ml amp data science developers for a new',
#  'b todays update on lockdown sceptics is here includes a post by will jones on an anomaly in the ons infection survey data',
#  'b  kenapa pilih judultopik ininapa urgensinyanapa yang menariknapa perbedaan penelitianmu dgn yg sebelum',
#  'bresearch dig amp consign  stunning chosen data in authors writers publishers readers  ',
#  'b this animation shows the hot and cold air masses over europe at 850 hpa tomorrow the dwd icon weather data provide this',
#  'b wales nasa kabilang bahay kami wala wifi tas mahina pa signal pang data',
#  'bi guess there is need to give us more information than just minting money from us i buy a wireless router 280k the ',
#  'b   havent seen data if it gets ema clearance i would trust that decisionnnhowever i doubt',
#  'bcovid vaccines former uk vaccines chief says yes to russian jab if data is good  via ',
#  'b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win',
#  'b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely',
#  'b la agencia tributaria reforzar con big data el control de espaoles que simulan residir en el extranjero ',
#  'b campaign against italy nonsense cainnnthis thread presents data that strongly reject claims that s problem has been a',
#  'b   easy to say but more complicated to actually implement its easy for ',
#  'b  2021 space shower music awards nn voting ends feb 28th 1159pm jst  kstnn  nominated for p',
#  'b  i think its widely known that the az oxford comms has been less than joined up the phase 3 data release and comm',
#  'b  its not bad news yet though as they dont have data on whether it protects against sev ',
#  'b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k',
#  'b interesting hospitalization data for children in england over the past few months nnsignificant change in the 05 yo categ',
#  'b       aicc data cell               ',
#  'b ',
#  'b could merck be strategic scaremongering bc not only did they just acquired a company for 425 million to develop a nove',
#  'bhave we just heard professor sarah gilbert on bbc telling andy marr that president macron and other countries not g ',
#  'brt datasciencectrl why you should use big data analytics in recruitment by tobias foster  ',
#  'b one example of the people who have been pushing corona failed policies why would we follow a dictatorship like ccple',
#  'b the department of homeland security dhs is being sued by center for democracy amp technology cdt for failing to respond t',
#  'b merck challenges safety amp validity of all ivermectin studies for covid19 despite having donated billions of doses to less',
#  'b mfs scared of government chips being implanted inside of us as if we dont walk around with 1000 data collecting farms in',
#  'b    my point is its data is useful',
#  'b the most exciting part about being a data science specialized solutions engineer ',
#  'bmain data source dostpagasa as of 4 pm phstnmodel references ecmwf gfsnprepared by r villanueva masd',
#  'b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k',
#  'b        ',
#  'bearly years settings are open to all children including those of stay at home parents',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b third and last day well track shoseki one piece holds its position phantom seer even manages to climb 1 place in the rank',
#  'b covid19nncovid194250035600',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit',
#  'bwhatshappeninginmaynmar nfightfordemocracy',
#  'b  ive used 5568 gb data since 10 iannnsidnaaz mvs in 100m club',
#  'b under 12 hour warning ndata collection for most shows ends in less than 12 hours along with the prevoting on ido',
#  'b for this piece i tried to gather together some thoughts about the serosurvey data coming out of india there is a great d',
#  'b join free odscwebinar to learn how to make utilization of opensource project dbt in order to build data pipelines for internal',
#  'b data giveaway by  nfollow him to benefit this sunday morningnnmake sure you rt',
#  'b massive study shows nnno instances of childto adult transmission of sarscov2 were reported within schoolsnnteachers un',
#  'b i had someone tell me the other day china has done better than the us at the coronavirus i said based on whos data',
#  'b hijabpaket data dan tiktok',
#  'b notable that az are open that they just dont have data on severe disease  the below is plausible i think but still not c',
#  'b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely',
#  'b i cant imagine a better group of folks to learn data science from ',
#  'b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps',
#  'bsarscov2infekte in deutschland grafik oben n5 feb 181 879 n6 feb 181 464nanzahl der aktuell sarscov2 ',
#  'b  macho que vives en manchester ',
#  'b alahai nnkalo sokong pakatan harapan yg atok jadi pm mengapa nak pinda perlembagaan utk kembalikan hak sarawak dan sa',
#  'b this week professionalising data stewardship in the netherlands competences training and education was published rea',
#  'b the movie  johnnys webnn ',
#  'b           ',
#  'bhi  nive been with you for thirty years nplease dont advertise with gb news or any other similar fox ne ',
#  'b hampir setahun 800 triliun dua juta data belum tercatat nnsebelumnya bisa sembuh sendirinnsemangatnnmerawatingat ht',
#  'b read the best account of why merck disavowed ivermectin a cold hard business decision with an element of strategic scar',
#  'b nnn ',
#  'b trial data also showing fewer asymptomatic infections which likely points to reduced transmission following vaccination',
#  'b  pengembangan negara maju dan berkembang bimbingan alumni ui nndisclaimer  jawaban ini ga 100 benar jadi kalau ada y',
#  'b 4 dr fauci the data really are quite suggestive the level of immunity that you get from natural infection  either the',
#  'b join free odscwebinar to learn how to make utilization of opensource project dbt in order to build data pipelines for internal',
#  'b update a neartotal internet shutdown is now in effect in myanmarnnnetwork data show a collapse of connectivity to 16 of',
#  'b  cara menyelamatkan filedatadata dari laptop yang sudah rusakmati total nna thread ',
#  'b massive study shows nnno instances of childto adult transmission of sarscov2 were reported within schoolsnnteachers un',
#  'b arria provides human language enhancing data amp voice reports in excel powerbi alexa qlik resultsbi uipath tibco ta',
#  'b merck challenges safety amp validity of all ivermectin studies for covid19 despite having donated billions of doses to l',
#  'b so i wrote a 5400word lecture note on the basics of data engineering for my students coveringnn data formats row vs colu',
#  'b really interesting data discussed at gm4women2028 nnwe encourage  to breakdown the score card by single',
#  'b we are focused on school shootings why not this our politicians copied policies of the ccp because the medical indu',
#  'b    95     nn    2019      8       ']

# %%
tf_batch = tokenizer(tweets, max_length=128, padding=True, truncation=True, return_tensors='tf')
tf_outputs = model(tf_batch)
tf_predictions = tf.nn.softmax(tf_outputs[0], axis=-1)
labels = ['Negative','Positive']
label = tf.argmax(tf_predictions, axis=1)
label = label.numpy()
for i in range(len(tweets)):
  print(tweets[i], ": \n", labels[label[i]])
# Out:
# b   the latter is bad news its plenty big enough until it trades as safely amp  :
#  Positive
# b overwhelming public opinion backs citizenship4soldiers njoin harry redknapp amp lewis moody in backing automatic citize :
#  Positive
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nn :
#  Negative
# b new york releases data on covid deaths at each nursing home  :
#  Positive
# b please remember that all digital plays of odd eye and rtu will contribute to end of year data which will be used for end o :
#  Positive
# b   i am sure they would be fascinating nnhowever more interesting and relev  :
#  Negative
# b data loss prevention strategies for longterm remote teams cybersecurity security   :
#  Positive
# b geo   nn   nngeo data block is building a decentralized peertopeer big data sharing ecosyst :
#  Positive
# b   you are not intelligent but just quick to reply without fully grasping what i sa  :
#  Negative
# b  new airdrop kragxnn total reward up to 36 krx 18  6 krx 3 per referralnn start the airdrop bot  :
#  Negative
# b n27rnnhttps :
#  Negative
# b fox news has a pretty toxic track record in the us  the last thing britain needs is more media like this  :
#  Negative
# b  if you care about your data you really should dive into the ocean  :
#  Negative
# bfightfordemocracynherethevoiceofmyanmar :
#  Negative
# b have thrice worked on tools to set up local databases from production datannis there a company that automates this for al :
#  Negative
# b our analysis of nhse covid19 vaccine data found that white ppl arenngt 3xs as likely as mixed ethnicitiesngt 15xs as likely as :
#  Negative
# b these numbers reflect the latest data available as of jan 29 from the cdcs vaccine adverse event reporting system v :
#  Positive
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# b data protection commissioner to regulate tiktok for all of europe  via  :
#  Positive
# b do care home staff know this do doctors know this  :
#  Negative
# bxsl  labs is a french project launched in the field of big datanand if you have any idea of data management i a  :
#  Positive
# b  have we got any data on sputnik :
#  Negative
# b   with a sample that size how old would you need the participants to be to ge  :
#  Negative
# b initial data indicate that astrazenecaoxford vaccine offers  limited practically nonexistent protection from coronav :
#  Negative
# bsecurity breach in ctd peshawar hq  nds mole gets ingress to classified data ig kp appoints a hacker to hack soci  :
#  Negative
# b sitepoint discloses data breach after stolen info used in attacks  :
#  Negative
# b please use the tagsnngot7  to 7 previous week 6 in the most mentioned kpop artists on twitter nnwhat is stopping you us :
#  Negative
# b lekker dan :
#  Positive
# b maricopa county refusing to turn it over is admitting to election fraud :
#  Negative
# b the uk vaccine project set out to deliver 146m doses by 15 feb its on course to get there by next saturday two days e :
#  Negative
# b hijabpaket data dan tiktok :
#  Positive
# bwe are probably the only company that is performing the full circle of design manufacturing composite electronic  :
#  Positive
# b save myanmar citizens d7nnwhatishappeninginmyanmarnmyanmarsnsfreedom :
#  Negative
# b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b naye nga dala omuntu atakulya lwaki aba akugulira data :
#  Negative
# b inm amp unicredit bank ireland were both run with with the high standards that chairman brian hillery of  :
#  Positive
# b    dapet data 99 darimana mas ngelakuin riset sendiri apa gimana dah wkwkwkwkw ga us :
#  Negative
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b under 12 hour warning ndata collection for most shows ends in less than 12 hours along with the prevoting on ido :
#  Negative
# b       mira un smbolo hind el objeto  :
#  Positive
# b lumayan soalnya kan abis donlot app harus donlot data lagi :
#  Positive
# b 14051800 nhknews  :
#  Positive
# b the department of homeland security dhs is being sued by center for democracy amp technology cdt for failing to respond t :
#  Positive
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# b please use the tagsnngot7  to 7 previous week 6 in the most mentioned kpop artists on twitter nnwhat is stopping you us :
#  Negative
# b hay que cerrarlo todo para acabar con el virus es cierto que si no acabamos con el virus primero no habr posibilida :
#  Positive
# b      ahhh we are at the gif stage but aga  :
#  Negative
# b  hapus mention yang terdapat data pelanggan ya terima kasih venti22 :
#  Negative
# b nn :
#  Negative
# b language model experiment  take a vague forecasting question what will the future of robotics look like g :
#  Negative
# b no data to prove ur point  flash floods and avalanches are common in any snow covered mountainsnnthe  :
#  Negative
# b i think one of the flaws in some peoples view of data science is that you have to code everything excel is a great too :
#  Positive
# b let the world know nwhatishappeninginmyanmar nmyanmarsnsfree :
#  Positive
# bxsl  labs is a french project launched in the field of big datanand if you have any idea of data management i a  :
#  Positive
# b okay i cant keep buying a masks and losing them like i have a job i already have data stressing me  :
#  Negative
# b time for a precautionary principle approach nour data adds to growing call for actionnppe ventilation  :
#  Positive
# b :
#  Positive
# b 1 analysing nct hashmask data on nn11 of supply is on exchanges in the last days we see an increase of :
#  Positive
# b  karena mereka butuh data aktifitasmu supaya bisa ngasih ads yang tepatnntarget ads tepat  makin besar kemun :
#  Positive
# b lumena a yg pode soltar a data do solos :
#  Positive
# b do care home staff know this do doctors know this  :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b  does he realise just how much electricity is needed to run the data centres and servers for h  :
#  Negative
# b i am today launching a small twitter initiative the campaign against nonsense about italy cani ill be tweeting data :
#  Positive
# b jan2021 heating data mean outdoor temp 32c typical night min 03c indoor mean 187c night 175c  :
#  Negative
# b how much is the average cost of a data breach in the healthcare industry :
#  Negative
# b businesses should begin assessing their data practices in order to meet the california privacy rights act requirements ht :
#  Negative
# b logistically speaking its impossible to deal with about 6b dead bodies over a 10y period without  :
#  Negative
# b indian drug regulator has denied emergency use authorisation to pfizers covid19 vaccine on the grounds that causality :
#  Negative
# b 2   n    n      nn2 weeks of mubeat awards votingncurious :
#  Negative
# bso if the average data was people in mid 30s how did they know the enhanced protection was due to the vaccine and  :
#  Negative
# bthe senior living digital marketing revolution needs call data   :
#  Negative
# btadi pagi komplen jawabannya begininsore ini nanyain lagi gmn progressnya eh dijawab begini juga nnudah lama pe  :
#  Positive
# b kak dede terkait kode error 45 14 berkenan informasikan nomor layanan internet dan nomor hp nya v  :
#  Positive
# b i think one of the flaws in some peoples view of data science is that you have to code everything excel is a great too :
#  Positive
# b hangi lkenin hangi alar kullandn gsteren bu tabloyu hazrlarken srbistan ayn anda 3 farkl a kullanan tek lke old :
#  Positive
# b campaign against italy nonsense cainnnthis thread presents data that strongly reject claims that s problem has been a :
#  Negative
# b kjre deg som mener var er en god ide det er lov  snu du kan endre mening noen vil til og med forvente at det skjer nr fa :
#  Negative
# bno question as you say   if we look at data rather than opinions maintaining strict borders to uk  :
#  Negative
# b the interesting political question is why now after de croo knot and all that a new spin  :
#  Negative
# bsave myanmar citizensnrevolutioninburmanwevotednld :
#  Negative
# bin data standards news the groups primary goal is to create an open source data commons that will make it easy  :
#  Positive
# b  apunta data per quan  pegui el bot  :
#  Positive
# b  good funding news nwere very pleased to have won a  bid so that we can loan out laptops amp wifi unit :
#  Positive
# b thanks  for the opportunity super excited to partner with you to help brands use data to best serve their customers h :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# beast hempfield weather data r 0445 am temp 354f humidity 66 wind 36mph se gust 98 mph  se rain 000 barometer 29994 :
#  Positive
# b the uk vaccine project set out to deliver 146m doses by 15 feb its on course to get there by next saturday two days e :
#  Negative
# bheres the first public version of raels polydrive his workinprogress mega drive synth instrument  :
#  Positive
# b all pension funds public and private have a fiduciary duty to hold bitcoin based on the data and fundamentals :
#  Positive
# b we fully reject military coup  save myanmar citizens d7 whatishappeninginmyanmar myanmarsnsfreedom :
#  Negative
# b if it will be slow it may be worth learning dma not that hard and can add a second core for e  :
#  Positive
# b ti ho seguita comunque si s posso seguire i profili essere seguiti puoi loggare  i film che  :
#  Positive
# bthis is excellent on the planning involved in getting the vaccination program running from development to issue  :
#  Positive
# b  is yet another paper with fantastic imaging arabidopsis roots from  :
#  Positive
# b 12netibnews   :
#  Negative
# b   there are 44 countries in europe and 4 have stopped using it and will r  :
#  Positive
# b help retweetnnsame as last week this week secretnumber retweets are only 5k dear  please post more on twitt :
#  Negative
# b 2 n  :
#  Negative
# b    95     nn    2019      8        :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked :
#  Positive
# b 1 analysing nct hashmask data on nn11 of supply is on exchanges in the last days we see an increase of :
#  Positive
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b childcare centres remaining open while schools have switched to remote learning for many pupils :
#  Negative
# b ministers use covid to take control over nhs england it will mean the slow dismantling of the nhs amp contracts being :
#  Negative
# borphnthe data from the disease in motion can be used for a multitude of different activities by potential custo  :
#  Positive
# b per reconsiderar les possibilitats de les utopies tecnolgiquesnnactualment els centres de dades consumeixen la mateix :
#  Positive
# b    95     nn    2019      8        :
#  Negative
# b fox news has a pretty toxic track record in the us  the last thing britain needs is more media like this  :
#  Negative
# b  nnsnowmann :
#  Positive
# b  :
#  Positive
# bdangerous data part 1 why the heat an effectiveness bank hot topic   :
#  Positive
# blearn it there are spying eyes everywhereand now they share a brain  via  tech digital data privacy :
#  Negative
# bvoi che avete messo in giro una falsa data per l ultima stagione di lcdp perch lo avete fatto :
#  Positive
# b     according to pfizers own research the immune system is compromised for a wee :
#  Negative
# b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely :
#  Negative
# b structured data extractionn n extract structured data across any siten validate against   google gu :
#  Negative
# b fox news has a pretty toxic track record in the us  the last thing britain needs is more media like this  :
#  Negative
# b check out the byline by our founder  on data regulation in 2021 in  this month nn :
#  Negative
# b benefits of being a datascientist professional via  abdsc  :
#  Positive
# bdata engineer  tech startup at  remote  apachespark :
#  Positive
# b  :
#  Positive
# b working to give people power in a new data economyn  founder of  nnhis mission resonate :
#  Positive
# baussies latest weather data 815 pm temp 185 humidity 57 wind 00 todays rain   00 :
#  Positive
# b let our voices be heard let the truth br prevailed save myanmar citizens d7nwhatishappeninginmyanmarnmyanmarsnsfreedom :
#  Positive
# b   have we got any data on sputnik :
#  Negative
# bweather data r 0445 am 231 67 pct 02 wnw :
#  Negative
# b 2   n    n      nn2 weeks of mubeat awards votingncurious :
#  Negative
# b what gets you going what gets you up in the morning what kind of change do you want to see learn how data science a :
#  Positive
# b the physicals for all biometric database purported to be a health initiative by china has also been proven part of mass :
#  Positive
# b   n  microsoft is investing aggressively in its azure cloud computing service particularly in :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# brt  embedded machine learning unlocks the potential of the currently unused enterprise data and enables  :
#  Positive
# b    :
#  Positive
# b sore kak mau tanya untuk update data diri di bank syariah itu bagaimana ya caranya karena sebel  :
#  Positive
# b artificial intelligence can do so muchninfographic by    nndata datascience ai artificia :
#  Negative
# b programming coding programmer javascript html machinelearning css 100daysofcode bigdata iot artificialintelli :
#  Positive
# b naver 210207nnbtsv aka prince of the continent ranked 1 among all korean celebs on aimans a chinese big data analys :
#  Positive
# b nnn1840577nn :
#  Negative
# bshout out to the best payment app n :
#  Positive
# b interesting hospitalization data for children in england over the past few months nnsignificant change in the 05 yo categ :
#  Positive
# b   do not go to tims website homefirstsuperseconddotcom nndo not leave your details therennti :
#  Positive
# b semoga menang yaallah bsk ada zoom meeting uangnya mau beli paket data :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# bkindly make the data public of the number of farmers death at protest site opportunistic congress are increasing t  :
#  Negative
# b bisp data cleaning under ehsaas governance framework in 2019bisp exited 820165 individuals from its beneficiaries li :
#  Positive
# b bisp data cleaning under ehsaas governance framework in 2019bisp exited 820165 individuals from its beneficiaries li :
#  Positive
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b   infatti perci data la mia non tenera et avrei suggerito a meloni  :
#  Positive
# b absolute proof summaryn2hr runtimenall 3 navarro repts evidence revisitednstarting on nov 1st white hat us h :
#  Negative
# b all the terrorists who stormed the capitol can be tracked down using their location data and i expect them all to be ar :
#  Negative
# b ppl selling databases of phone numbers to bizs in kenya ampbizs who buy the databases then send mass texts to subjects who :
#  Negative
# bthe astrazenecca vaccine to be treated like flu vaccine annual updating might be required to cover variantsndelay  :
#  Negative
# b nn  :
#  Negative
# b 1 analysing nct hashmask data on nn11 of supply is on exchanges in the last days we see an increase of :
#  Positive
# b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k :
#  Positive
# bdata 0945 pressure 10023 hpa temp 06oc hum 96pct wind 65 mph nnw rain today   51 mm month 368 mm snowfall today 00 snow depth0 :
#  Negative
# b subsidies and public spending need to be prioritised  evidence based that in how much aggregate soci  :
#  Negative
# bi can find no concrete data on how much lighter zephyr actually is disappointing :
#  Negative
# b same problem here the network here in gadau is very bad even for calls talkless of data :
#  Positive
# b third and last day well track shoseki one piece holds its position phantom seer even manages to climb 1 place in the rank :
#  Positive
# banother great start to the day dont we need someone explaining the practicalities here from gvmt if we need to  :
#  Positive
# b pm imran khans govt has been making claims about its economic performance based on the improvement on current account and :
#  Positive
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# bnn the movienn :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# bsch tmn2 mau nanya dong klo validasi data ltmpt itu alamat yg dipakai alamat tinggal saat ini atau alamat sesuai  :
#  Negative
# b the ccp and affiliated authorities are using artificial intelligence to scan massive amounts of data on communication apps fre :
#  Negative
# b   usb data     :
#  Positive
# bpart of the plan legitimate cull of elderly people :
#  Negative
# b and there is 1 psychiatrist for each 85000 lebanese mentalhealthawareness psychiatry  :
#  Positive
# b yes  is the most dangerous person in nhes deaf to data deaf to real stories deaf to hundreds of m :
#  Positive
# b check out the byline by our founder  on data regulation in 2021 in  this month nn :
#  Negative
# b  you can use alot of the data on the covid tracker app to analyse this we seem to be on a plateau now :
#  Negative
# b nnn1n2n3 :
#  Negative
# b these numbers reflect the latest data available as of jan 29 from the cdcs vaccine adverse event reporting system v :
#  Positive
# b my point is this when it comes to how the world has dealt with the coronavirus you would have to say we chose the chi :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b   january 19 was because of a data lag notice no vaccinations were reported in the previous days :
#  Negative
# b the uk vaccine project set out to deliver 146m doses by 15 feb its on course to get there by next saturday two days e :
#  Negative
# ball of nsw most of tas some of qld and little parts of sa and vic are covered ill analyse the lidar data and te  :
#  Positive
# b data giveaway by  nfollow him to benefit this sunday morningnnmake sure you rt :
#  Negative
# b this is a really helpful matrix for any powerquery user either in excel powerbi ssas or dataflowsnn  :
#  Positive
# b nnnnnnnnnn12800nn nn nniodata exldh241dbnn :
#  Negative
# bvous pouvez rt a svp :
#  Positive
# b any person who claims to be an expert economist who doesnt have an advanced knowledge of math shouldnt b  :
#  Negative
# b its no secret that we  lakehouse architecture but when it solves so many common issues with data warehouses amp improves :
#  Positive
# b 14051800 nhknews  :
#  Positive
# b no mbamalgalicia estreamos a seccin big data analytics na que  e  do  nos trouxer :
#  Positive
# b create your free account big data fundamentals with pyspark learn the fundamentals of working with big data with pyspark :
#  Positive
# b2 permeabilitygoogle mapslive traffic :
#  Negative
# b    :
#  Positive
# b settings  storage  apps  clear data and clear cache :
#  Positive
# b an out of the box campaign with market potential supported by raw data could lure investors :
#  Negative
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# bchina launches public data platform to trackpollution  :
#  Positive
# b  and downing street claims it doesnt recognise the traders data and falsely claims tra  :
#  Negative
# b the movienn :
#  Negative
# b when discovered seianti hanunia tlesnasas skeleton was still inside her sarcophagus the british museum has therefore been ab :
#  Negative
# b the movie  johnnys webnnsnowmannew  :
#  Negative
# b level up your data science vocabulary affinity matrix  machinelearning affinitymatrix :
#  Positive
# bnn :
#  Negative
# b  kpop artists next big sound social metrics weekly tallynndata collected from january 23 to 29  :
#  Positive
# b the objective data disagreesnn2 recessions record unemployment record insecurity amp record national disunity :
#  Positive
# bsave myanmar citizens d7nnwhatishappeninginmyanmarnnwevotednld nmyanmar people ag :
#  Negative
# b im sure tils and sng will have similar results on patients with moderatesevere illness 100 of p  :
#  Positive
# b they stormed the capitol their apps tracked themntimes opinion was able to identify individuals from a trove of leaked s :
#  Negative
# b 3 the preliminary finding from the  vaccine trial placebo group based on a data set with limitations stirred debate :
#  Negative
# b ministers use covid to take control over nhs england it will mean the slow dismantling of the nhs amp contracts being :
#  Negative
# b airtimedata giveaway nn follow n n rt this tweetnnlets goooo :
#  Negative
# b    dapet data 99 darimana mas ngelakuin riset sendiri apa gimana dah wkwkwkwkw ga us :
#  Negative
# b check out the byline by our founder  on data regulation in 2021 in  this month nn :
#  Negative
# b  the movien27 1600nnnnn n  web 300n :
#  Negative
# b :
#  Positive
# b the interesting political question is why now after de croo knot and all that a new spin  :
#  Negative
# b  not that theyve said but thats why id be concerned its the reason why you anonym  :
#  Negative
# b new book out on using tidyverse tools for data science written with   and   :
#  Positive
# b :
#  Positive
# b great these last few weeks to have worked on a number of projects including on nps housing arrearsplanned maint and da :
#  Positive
# bproses vaksinasi di indonesia yang berjalan sangat lamban adalah contoh nyata dari kombinasi buruknya manajemen da  :
#  Positive
# b price data is daily live :
#  Positive
# b campaign against italy nonsense cainnnthis thread presents data that strongly reject claims that s problem has been a :
#  Negative
# b uploads cvngt thank you now please input the same data broken up into these 36 form fields :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# b 2   n    n      nn2 weeks of mubeat awards votingncurious :
#  Negative
# b no mbamalgalicia estreamos a seccin big data analytics na que  e  do  nos trouxer :
#  Positive
# b uploads cvngt thank you now please input the same data broken up into these 36 form fields :
#  Positive
# bchosun online    nn  :
#  Positive
# b 4 dr fauci the data really are quite suggestive the level of immunity that you get from natural infection  either the :
#  Negative
# bnigerians stop playing policies with the economy you will keep getting porter if you do say the truth so the prob  :
#  Positive
# b kalau pake data seluller ganti pake wifi sebaliknya aku jga gitu tdi pake data kuganti pake wifi bisa  :
#  Negative
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# b zeer zorgwekkende berichten uit engeland over ziekenhuisopnames en mis onder kinderen zie ook de trend nde scholenope :
#  Positive
# b i asked my friend to buy me data she legit asked me nze akuzina nnmaze okwesabyasabya :
#  Negative
# b  :
#  Positive
# besse aqui  meu nico tweet sobre o bbb sem data de validade :
#  Positive
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# b   :
#  Positive
# b please for the love of svt rt  tweets  the differences between rts and likes are waaaay too big and t :
#  Negative
# b i recently had an energy provider change imposed and i am not a fan of the data shown on their webs  :
#  Negative
# bci provo a modo mio spiegare almeno 1 vantaggio pratico di avere un phd nngt   :
#  Positive
# b como sigamos llamando inteligencia artificial machine learning y big data a todo lo que no sale de un spss random for :
#  Negative
# bjust watched attack on titans with my data plan cause i forgot to turn on the damn wifi  :
#  Negative
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# bdoes that mean other countries have more covid19  vaccine data  marr :
#  Negative
# b mike yeadon former vp and chief scientist at pfizer one of the most important information sources has been cancelled :
#  Negative
# b      nn                        :
#  Negative
# b  hopefully thats kujata  although yoship just announced that they are adding data centre visit  :
#  Negative
# b   i think recent events over the last quarter have also promoted you  :
#  Positive
# b shocking hospitalization data for children in england over the past few months nnsignificant change in the 05 agegro :
#  Negative
# b :
#  Positive
# b science data and tech are coming together like never before to deliver breakthroughs that will transform human health o :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b  the movien27 1600nnnnn n  web 300n :
#  Negative
# b you bring the clients ileads provides the best real estate data and the best mortgage and insurance leadsnyou solve your c :
#  Positive
# b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely :
#  Negative
# b    per aix no sha deixat canviar la data perqu la gent no  :
#  Positive
# bfake environmental activists activated if they blame dams and roads tell them downstream lutyens is safe because  :
#  Negative
# b   again in ga and there was court cases still in the courts where rep states had  :
#  Positive
# b mike yeadon former vp and chief scientist at pfizer one of the most important information sources has been cancelled :
#  Negative
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b jya muri settingsgtappsgttwittergtstoragegtclear datanubundi uyifungure uhindure password :
#  Positive
# bchina is launching a public data platform to name and shame polluters  :
#  Positive
# b  from the creator a link between nodes means that both accounts were retweeted mu  :
#  Negative
# b    95     nn    2019      8        :
#  Negative
# b  yes but the question is ndo you trust the use of the data :
#  Negative
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# b ekonom senior yang juga mantan menko perekonomian kwik kian gie beradu data dan argumen soal utang indonesia dengan staf kh :
#  Positive
# b science data and tech are coming together like never before to deliver breakthroughs that will transform human health o :
#  Positive
# b omars campaign was by far its biggest moneymakerdolingout 146 checks for 29 million or 78 percent of the firms :
#  Positive
# b point nya senang je berhenti la trend false advertisement demi nak dapatkan data orang jijik gila perangai :
#  Negative
# b methane ch potent greenhouse gas reached a preliminary record high value in october 2020 18909 ppb note there is a sea :
#  Positive
# b   touche nope didnt compare the people i asked if the database was going to  :
#  Negative
# b   :
#  Positive
# bnew feb sec filing by legend s  aims for 15 aggregate investment in bitcoin exposure  :
#  Positive
# b new guidancennensuring we do no harm while maximizing the benefits of data requires collective action that extends across :
#  Positive
# b itna kum  itne ki toh main apne friends ko gifts de deti hoon  kitne saste hain yeh sab yaar hahahaha biggest f :
#  Positive
# b trump it wasnt menscience pretty sure it was you :
#  Negative
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# b the movienn :
#  Negative
# b  we agree darren and we will be working with the local highways authority to undertake  :
#  Positive
# bsave myanmar citizens d7nwhatishappeninginmyanmarnmyanmarsnsfreedom :
#  Negative
# b start learning for free hierarchical and recursive queries in sql server learn how to write recursive queries and query hier :
#  Positive
# b 2 juta data wabah disumputin terus gegayaan mau digitalisasi sertipikat tanah dumb evil is dumb evil  :
#  Negative
# b its either data capture exhortations for money or porn or sometimes a combo its across pretty much  :
#  Negative
# b12 3860000n :
#  Negative
# b uploads cvngt thank you now please input the same data broken up into these 36 form fields :
#  Positive
# b create your free account multivariate probability distributions in r learn to analyze plot and model multivariate data h :
#  Positive
# bcustomer service in dubai united arab emirates service data customer entry product shift  :
#  Negative
# b few days ago i accompanied a friend for verification and data capturing as a duly registered member of one of the leading :
#  Positive
# b rent arrears in the socialhousing sector have exceeded 1bn during the covid19 pandemic data has revealed  :
#  Positive
# b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit :
#  Positive
# bvenezuela jails officials for giving us oil datann  :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b the first major campaign launched by the  team is underwaynncomplete a list of micro tasks to enable us to :
#  Positive
# b what is  motive in pitting  vs  nthis is evilnboth r digital partners to get ahe :
#  Negative
# b pinterest seo 12 tips to optimize your pins for searchnn nadtech advertising datamining ap :
#  Positive
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b fyi ive relinked my mobile number having to use a spare phone because it would not allow me to buy  :
#  Negative
# b uploads cvngt thank you now please input the same data broken up into these 36 form fields :
#  Positive
# b a swiss tech company believes its found a security weakness that could jeopardize the confidentiality of the worlds interne :
#  Positive
# b should be repeatedndominion denies anybody this happened but is also fighting tooth amp nail to keep anyone from investig :
#  Negative
# b  nn 19 :
#  Negative
# b to us who will not receive even 1gh biscuitmay god provide us with money to buy dataso we can view status  :
#  Positive
# b                    :
#  Positive
# b   under the guise of other religions ethnic terrorists have formulated an idea t  :
#  Negative
# b  sir pls look into the matter as per data published on newspaper     :
#  Positive
# b nnn1840577nn :
#  Negative
# b if all those online certificates in data analysisartificial intelligence amp machine learning which people never fail to :
#  Positive
# bhau non ha mai sconfitto hala glielha data vinta semplicemente perch hau  suo nipote e gli fa pena :
#  Positive
# b my new hobby is taking graphs of economic data over time and indicating the year that ronald reagan was inaugurated in ca :
#  Negative
# bupdate data uji pcr covid19 di indonesia per tanggal 7 februari 2021 pukul 1200 wib bersamalawancovid19  :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b como sigamos llamando inteligencia artificial machine learning y big data a todo lo que no sale de un spss random for :
#  Negative
# b thisnthingnannoysnmynsoul :
#  Negative
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b venezuela jails officials for giving us oil datann  :
#  Negative
# bbut thats just reported ones much like abused women numbers in reality are so much higher  :
#  Negative
# b if you believe this sponsored report that uses irish data from 1922 youll believe anything ev  :
#  Positive
# b using a trove of leaked smartphone location data  and  identified some of the capitol rioters :
#  Negative
# b   mungkin saya yang kelewat rajin baca sih sampe data beginian saja saya dapet hehe  :
#  Positive
# b     see his profile hes been publishing timeline data :
#  Positive
# b our analysis of nhse covid19 vaccine data found that white ppl arenngt 3xs as likely as mixed ethnicitiesngt 15xs as likely as :
#  Negative
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# b pleased that data from our  diagnostics and sequencing team could contribute to these analyses about spread :
#  Positive
# b    95     nn    2019      8        :
#  Negative
# bthese viruses can be fascinatingly beautiful  :
#  Positive
# b update as crowds gather for a second day of anticoup protests in myanmar realtime network data show the country remains :
#  Positive
# b marital rape is punishablenbut how many have been punished for nikah halalando you have any data for that :
#  Positive
# bas an interviewer judging a candidate on this aspect is similar to judging a content creator who is comfortable amp f  :
#  Negative
# b campaign against italy nonsense cainnnthis thread presents data that strongly reject claims that s problem has been a :
#  Negative
# b7 best tools for structured data schema testing amp execution via   freelancers  :
#  Positive
# b we are seeking 2 postdocs to join our team 1 experimental biology examining therapeutic benefits of correcting rare :
#  Negative
# b if your account was disabled you can download and save your data learn more about this here  :
#  Positive
# b really good article with excellent interpretation of the published data by ni think we know the answer is a res :
#  Positive
# bwhat does this mean in areas with high proportion of people of colour it is impossible to understand how covid19  :
#  Negative
# bkebakaran menghanguskan dua unit komputer dan cpu yang berisikan data penjualan sepeda motor dan suratsurat kendar  :
#  Positive
# bpfizerbiontech new data on vaccine effectiveness against uk strain   update from pfizer  :
#  Negative
# b if you were a eu citizen who stormed the united states capitol on january 6th you might be eligible for compensation from p :
#  Negative
# bmy isp is down again mobile data is still working for now even if they cut off everything again know that we are  :
#  Negative
# b stuck in twitter amp nationalist media echochambers rw chowkidars refuse to see the writing on the wall what started as :
#  Negative
# b absolute proof summaryn2hr runtimenall 3 navarro repts evidence revisitednstarting on nov 1st white hat us h :
#  Negative
# b bisp data cleaning under ehsaas governance framework in 2019bisp exited 820165 individuals from its beneficiaries li :
#  Positive
# b these viruses can be fascinatingly beautiful   :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b yesterday we heard from the government in our covid19 data inquiry the   ministers delegated :
#  Negative
# b  kpop artists next big sound social metrics weekly tallynndata collected from january 23 to 29  :
#  Positive
# b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit :
#  Positive
# b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely :
#  Negative
# b what is  motive in pitting  vs  nthis is evilnboth r digital partners to get ahe :
#  Negative
# b finder an automated software package to annotate eukaryotic genes from rnaseq data and associated protein sequences :
#  Positive
# b now 3 vaccines have been shown to have diminished efficacy against b1351 south african all prevent death and hospitaliz :
#  Negative
# b in chicago 80 percent of gunviolence victims in 2020 were black according to the latest data in new york city 71perc :
#  Positive
# b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k :
#  Positive
# b  where to lodge complaint against digital lending app  contact list we have proof they are using user con :
#  Negative
# b the movie  johnnys webnnsnowman   :
#  Negative
# b :
#  Positive
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# bdata from my cellar thanks to electric imp discover kit temp 1421  humid 13867  pressure 97225 :
#  Negative
# bwhile im optimistic about us vaccination progressit is still going to take them months to clamp down on some of t  :
#  Negative
# b  nn 19 :
#  Negative
# bstart learning for free data visualization in r this course provides a comprehensive introduction to working with  :
#  Positive
# b venezuela jails officials for giving us oil datann  :
#  Negative
# b the interesting political question is why now after de croo knot and all that a new spin  :
#  Negative
# b powerbi blogpost  :
#  Negative
# b you can delete messages chats call history and groups you created at any time deleted items completely disappear for all p :
#  Negative
# bbitwarsoft bitwar data recovery  data recovery software for windowsmac  :
#  Positive
# b i am today launching a small twitter initiative the campaign against nonsense about italy cani ill be tweeting data :
#  Positive
# b uop for surenn provides a base for the music industry that everyone can benefit from   :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# bthis is the most inefficient big data tool ever i dont even see it breaking into the tech space :
#  Positive
# b a must watch for allworthy of your time data and attention     https :
#  Positive
# b vir a tool to solve intrasample variability in the prediction of viral integration sites using whole genome sequencing :
#  Positive
# b absolute proof summaryn2hr runtimenall 3 navarro repts evidence revisitednstarting on nov 1st white hat us h :
#  Negative
# b   i like the idea in the article of thinking in terms of cold and warm data  :
#  Positive
# b jste zodpovdni a vy speciln jako lka za zpochybovn opaten vldy s dopadem na veejnostkterou t  :
#  Positive
# b workers who have decied to stay put celebrated the upcoming spring festival together at the construction site of the huawei clou :
#  Positive
# b  :
#  Positive
# b   so apparently asking for my number was just for data base pathetic customer service :
#  Negative
# b  :
#  Positive
# b  guess what i have missednnantother databreach sitepoint handed over user data to unknown 3rd partynn https :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b fox news has a pretty toxic track record in the us  the last thing britain needs is more media like this  :
#  Negative
# b having received substantial public funding we encourage all manufacturers to share their data and technologynnwho chief h :
#  Negative
# bbeberd off his fking data :
#  Negative
# b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k :
#  Positive
# b data detox kit  zure pribatutasun segurtasun eta ongizate digitala egoki iruditzen zaizun moduan kontr :
#  Positive
# b douluoday2nhow can ixfx watch and increase popularity for douluo continentnn1 watch online on  app watching on this :
#  Positive
# b most important bit of evidence weve seen so farnnticktock :
#  Positive
# b you bring the clients ileads provides the best real estate data and the best mortgage and insurance leadsnyou solve your c :
#  Positive
# btay tawan ti devo ricordare la tua data di nascita :
#  Positive
# bdata26nnnn1n242nn2n5  :
#  Negative
# b all  who authorized are stupidnndo you think you are talking to childrennnthey warned fg fbn so why hav :
#  Negative
# b statistics the science prove children resilient the government amp  had zero reasons to close schools  :
#  Negative
# b   do not go to tims website homefirstsuperseconddotcom nndo not leave your details therennti :
#  Positive
# b nn :
#  Negative
# b do care home staff know this do doctors know this :
#  Negative
# b social media research  present socialmedia network analysis n reduced academic priceninfo  http :
#  Negative
# b  i find the app more than cumbersome sorry  you can only buy the coins in a roundabout way  :
#  Negative
# bwhatshappeninginmyanmar fightfordemocracy :
#  Positive
# bheden tracken wij kapitoolbestormers morgen zijt gij aan de beurtnthey stormed the capitol their apps tracked t  :
#  Negative
# b   do not go to tims website homefirstsuperseconddotcom nndo not leave your details therennti :
#  Positive
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# b    n   because its one hell of a ride nan in depth analysis of official ons :
#  Positive
# b my new hobby is taking graphs of economic data over time and indicating the year that ronald reagan was inaugurated in ca :
#  Negative
# b to us who will not receive even 1gh biscuitmay god provide us with money to buy dataso we can view status  :
#  Positive
# b should be repeatedndominion denies anybody this happened but is also fighting tooth amp nail to keep anyone from investig :
#  Negative
# b nnn :
#  Negative
# bthe owner of this account data is probably too obvious to even bother mentioning  :
#  Negative
# b  statistics the science prove children resilient the government amp  had zero reasons to close schools to be :
#  Negative
# b british drugmaker astrazeneca said on saturday its vaccine developed with the university of oxford appeared to offer only li :
#  Negative
# b nn :
#  Negative
# b i read the paper referenced in this article and its a subjective study that correlates positive mood  :
#  Positive
# bstumbling across a compendium of data that ive always dreamed of ndefinitely going to be digging into their met  :
#  Negative
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# b 1 so europe has its own adverse events reporting system for drugs and vaccines called eudra it now has data for the co :
#  Positive
# b et aprs on ose dire quon est encore dans une dmocratie coronafolie dictaturesanitaire :
#  Positive
# b tamb li podem donar la volta i dir que els indepes que anirn a votar en unel eleccions amb data impo  :
#  Positive
# b sebuah utas nthread  by   ncc  :
#  Negative
# bworkers collect a handheld scanner that records their every move for the next 10 hours feeding productivity data  :
#  Positive
# bsabe magpatulong daw kay maam kim pag may hindi alam sa treatment of data kaso mo hindi ko naman alam kung anon  :
#  Positive
# b   do not go to tims website homefirstsuperseconddotcom nndo not leave your details therennti :
#  Positive
# b how can ixfx watch and increase popularity for ndouluocontinentnn1 watch online on  app watching on this app is no :
#  Negative
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely :
#  Negative
# bmantep tiap hari dicicil naik 01 :
#  Negative
# btelenor myanmar has restored cell service after the military shut it down  reminder from :
#  Positive
# b nnn1n2n3 :
#  Negative
# b quick explainer on using an esim in myanmar with roaming data nn nmyanmar :
#  Negative
# b language model experiment  take a vague forecasting question what will the future of robotics look like g :
#  Negative
# b venezuela jails officials for giving us oil datann  :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# bno more silencennwhatshappeninginmyanmarnfightfordemocracy :
#  Negative
# b    you understand we left a month ago right i doubt anyone  :
#  Negative
# b i want to draw attention to a new page in documentation that was published with little fanfare  did a great :
#  Negative
# bwe should conduct our elections with that same integrity most in dc dont have integrity to begin with just say  :
#  Negative
# bdata viitoare cand m mai deschid n faa cuiva va fi la autopsie  :
#  Positive
# b selamat sore railmin bantu cek silakan diinformasikan data yang dikirim via dm ya trims :
#  Positive
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b 800g test from keysight technologies validates nextgen data centres keysight technologies has released  :
#  Positive
# blasie aime trop luffy et cest normal :
#  Positive
# bon the comments of president  professor sarah gilbert tells  that we will have efficacy  :
#  Negative
# b part 3 of decodeme team member annas transcript of decembers winter webinar is now available to read on her blognngo :
#  Positive
# bdata pcrpost  :
#  Negative
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# b   because the data coming out of china can be relied upon they can be trus  :
#  Positive
# b  big data es cualquier cosa que convierta una query sql en grficas de lneas o de barras e  :
#  Positive
# b   wawww 99  data dari mana mas   :
#  Negative
# b you bring the clients ileads provides the best real estate data and the best mortgage and insurance leadsnyou solve your c :
#  Positive
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b this is quite important but remember everyone all characters have different dash gt shield data corrin and sheik are th :
#  Positive
# b data design should clarify and not necessarily simplify    :
#  Positive
# b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely :
#  Negative
# b    dapet data 99 darimana mas ngelakuin riset sendiri apa gimana dah wkwkwkwkw ga us :
#  Negative
# b added to the pile of ivermectin data for covid marked statistical significance of becoming covid pcr negative sooner :
#  Negative
# b should be repeatedndominion denies anybody this happened but is also fighting tooth amp nail to keep anyone from investig :
#  Negative
# b while in the military i pointed this out as a flaw in personnel statistics that required peercomp  :
#  Negative
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b our cdc followed the ccps lead why didnt they follow taiwans recommendations why didnt the who listen to taiwan :
#  Negative
# b    again try to understand issues before projecting your jaudiced  :
#  Negative
# b in december ethiopias information network security agency claimed that the tplf was producing over 20000 tweets containin :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# bwho knows where to find data for daily trades volume for crypto currencies :
#  Positive
# ba briga desse dia :
#  Positive
# b the objective data disagreesnn2 recessions record unemployment record insecurity amp record national disunity :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# bnice to see  organising a pretty cool training event on analysing socialmedia data for academic res  :
#  Negative
# bdynamic service chaining in a data center with nexus infrastructure   :
#  Positive
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b210207   nn txtn   nn  nn  data :
#  Negative
# b excited to bring my workshops online join me to discuss dataviz sketch some data stories and improve your infogr :
#  Positive
# bthey took our freedom of speech   :
#  Negative
# b artificial intelligence can do so muchninfographic by    nndata datascience ai artificia :
#  Negative
# ...
#  Positive
# bare you going to reply my dm or not :
#  Negative
# b once peeped this thanks to  app i was actually tracking my data usage for the month ndakuona tinder as one :
#  Negative
# b 3  n187164121117n937269n54503030n27 n :
#  Negative
# b visual proof they went to the capitol for him he asked them to go he asked them to stop what was going on they tried and :
#  Negative
# b this is indeed shaping up to be a key year for dataregulation as proclaimed  in the  article  :
#  Positive
# btodava no me puedo creer que vayan a meter data center travel en el ff14 podre jugar con amigos de europa o inclu  :
#  Positive
# b screams in data :
#  Negative
# b hearthevoiceofmyanmar helpmyanmar silencedvoicesinmyanmar :
#  Negative
# b top 15 free datascience machinelearning amp statistics books for 2021 by  nn :
#  Positive
# bfor me as a scientist this is beyond disgrace faking scientific data to justify lockdown  people are sufferin  :
#  Negative
# b unfortunately most people dont understand the importance and legal aspects of information governance  :
#  Negative
# b 2   n    n      nn2 weeks of mubeat awards votingncurious :
#  Negative
# b ekonom senior yang juga mantan menko perekonomian kwik kian gie beradu data dan argumen soal utang indonesia dengan stafsus :
#  Positive
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b  sadly jane doesnt understand the data :
#  Negative
# b pakistani armysnpakistan is at 33 with 139m views in last weeks datan30 jan5th febnour goal for this week is 16m :
#  Negative
# b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit :
#  Positive
# b 4 1n8151093n816261745283304n7983n https :
#  Negative
# b my prediction was correctsweden just surpassed the peak they had in aprilnndue to reporting delays its only today that f :
#  Positive
# b i was honored to help launch  global report on traffickinginpersons all governmentseveryone else must read for cru :
#  Positive
# b opinions is one thing heres the facts using fbref data for the current season there is less stoppag  :
#  Negative
# b all  who authorized are stupidnndo you think you are talking to childrennnthey warned fg fbn so why hav :
#  Negative
# bla gira con los pibes tienen mucha data :
#  Positive
# b  we did not have finegrained data on type of mask surgical vs ffp2 or use of oth  :
#  Negative
# b breaking the first realworld data from the uk vaccine rollout shows promising evidence that justifies the delayed s :
#  Negative
# bits strange how despite all the investment and advances in data science and computation we still cant predict th  :
#  Negative
# b pan  mohli bychom vidt et za natoen propaganho videa o cench respirtor kter jste zveejnila a :
#  Positive
# b i gotta head out tocause i mean i obviously want to hear how her heart is doing but yall take care ill pop in now :
#  Negative
# b precisa baixar o preo da gasolina e lcool tambm aqui em salvador na data de ontem 0602 fizera  :
#  Positive
# b maricopa county refusing to turn it over is admitting to election fraud :
#  Negative
# bhm hahaha :
#  Negative
# b helix technologies inc hlix cannabis fintech medicalmarijuana medical data storage hipa stocks billio :
#  Positive
# bun espai per compartir i seguir apostant per una metodologia que transforma l  educaci i el mn  :
#  Positive
# b a partir de lundi le monde rvle openlux une dataenqute dun genre nouveau sur le luxembourg en collaboration avec  :
#  Positive
# buseful for anyone looking at pupil premium and policies around disadvantaged pupils what might this data suggest  :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# bcurrently overcast and 17 f at cleveland hopkins international airport oh winds are southwest at 81 mph 7 kt  :
#  Negative
# b helix technologies inc hlix cannabis fintech medicalmarijuana medical data storage hipa stocks billio :
#  Positive
# bapplynow la scuola superiore santanna promuove la seasonalschool the responsible data societynnel video i temi  :
#  Positive
# b its strange how despite all the investment and advances in data science and computation we still cant predict the weather ac :
#  Positive
# b really take a moment to ponder thisnthe maricopa board of electors are willing to go to jail by ignoring subpoenas and h :
#  Negative
# bmurdering hornets step aside :
#  Negative
# b worth a read   :
#  Positive
# bomo this is the reality of thousands of nigerians unable to properly feed this man doesnt think of data or acce  :
#  Negative
# bhere is a prime example of fake climate science deliberately altering data to suit their real agendanits fraud :
#  Negative
# b hai mohon maaf kak aditya sistem kami sedang dalam proses pembaharuan data keluhan kakak tetap dicata  :
#  Positive
# b which countries are most exposed to floods and where does floodrisk and poverty intersect  check out these new interactiv :
#  Positive
# b red skies saharan dust makes it to switzerland nsince our operational snow models do not yet account for these type of :
#  Negative
# b  hallo you can read it here campaign against italy nonsense cain this thread presents data that stron :
#  Negative
# b  settings  installed apps click on twitter  clear cache and datanrahul vaidya for the win :
#  Positive
# b emm mai ne abi tk mobile data use b nahi kiya hai wallah nmai rusith hu mje nahi chahiye :
#  Negative
# b since the day wey i sabi transfer buy data n airtime from my bank my life no balance again  :
#  Negative
# b thread da leggere con attenzione conservare e sbattere in faccia  allidiota di turno che ciancia di compiti a casa che :
#  Positive
# b 14051800 nhknews  :
#  Positive
# b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k :
#  Positive
# b      :
#  Positive
# b breaking the first realworld data from the uk vaccine rollout shows promising evidence that justifies the delayed s :
#  Negative
# b if you got picked njust dm me details to collect your winningnegnif you want data 1gb  081 mtn 1gb n500 airtime :
#  Positive
# b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit :
#  Positive
# bcciv :
#  Negative
# b key data has been deleted from govts debt report indicators on total public debt as  of total revenue debt service co :
#  Negative
# b  i bought wifi private bundles for 8gig and hourly for 1gig via ecocash but i haven  :
#  Negative
# b  i couldnt agree more it certainly doesnt serve the masses as well as it could rig  :
#  Positive
# b mapping lightning strokes  :
#  Positive
# b top 15 free datascience machinelearning amp statistics books for 2021 by  nn :
#  Positive
# b52 of the companies had accelerated their adoption of ai due to the pandemic and nearly 25 of them had fully emb  :
#  Positive
# b nn :
#  Negative
# b  we did not have finegrained data on type of mask surgical vs ffp2 or use of oth  :
#  Negative
# b here is a prime example of fake climate science deliberately altering data to suit their real agendanits fraud http :
#  Negative
# b this is not good news 2026 pts in sa  hiv neg young median 31 yrs az vax not protective against mild mod infection no :
#  Negative
# b over 1m ppl are now gathering at yangon townhall phone internet data is restored but not sure when itll be blocked mya :
#  Negative
# b hold onwaitlast monday dr anthony fauci said that wearing two masks likely made it safer but now this week dr :
#  Negative
# bthe absence of data on the efficacy of astrazeneca vaccine in over 65 renders those eu countries that have refused  :
#  Negative
# bwashington state introduces new data privacy bill the peoples privacy actn   :
#  Negative
# b    pode mandar print qual a data da edio :
#  Negative
# b verox status report 3 is now outnnmajor updatesn we have hired another 3 ai ml amp data science developers for a new :
#  Negative
# b todays update on lockdown sceptics is here includes a post by will jones on an anomaly in the ons infection survey data :
#  Negative
# b  kenapa pilih judultopik ininapa urgensinyanapa yang menariknapa perbedaan penelitianmu dgn yg sebelum :
#  Positive
# bresearch dig amp consign  stunning chosen data in authors writers publishers readers   :
#  Positive
# b this animation shows the hot and cold air masses over europe at 850 hpa tomorrow the dwd icon weather data provide this :
#  Positive
# b wales nasa kabilang bahay kami wala wifi tas mahina pa signal pang data :
#  Positive
# bi guess there is need to give us more information than just minting money from us i buy a wireless router 280k the  :
#  Negative
# b   havent seen data if it gets ema clearance i would trust that decisionnnhowever i doubt :
#  Negative
# bcovid vaccines former uk vaccines chief says yes to russian jab if data is good  via  :
#  Negative
# b budde ko bolo livefeed on kare nni am saving my data packnnrahul vaidya for the win :
#  Negative
# b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely :
#  Negative
# b la agencia tributaria reforzar con big data el control de espaoles que simulan residir en el extranjero  :
#  Positive
# b campaign against italy nonsense cainnnthis thread presents data that strongly reject claims that s problem has been a :
#  Negative
# b   easy to say but more complicated to actually implement its easy for  :
#  Positive
# b  2021 space shower music awards nn voting ends feb 28th 1159pm jst  kstnn  nominated for p :
#  Negative
# b  i think its widely known that the az oxford comms has been less than joined up the phase 3 data release and comm :
#  Negative
# b  its not bad news yet though as they dont have data on whether it protects against sev  :
#  Negative
# b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k :
#  Positive
# b interesting hospitalization data for children in england over the past few months nnsignificant change in the 05 yo categ :
#  Positive
# b       aicc data cell                :
#  Negative
# b  :
#  Positive
# b could merck be strategic scaremongering bc not only did they just acquired a company for 425 million to develop a nove :
#  Negative
# bhave we just heard professor sarah gilbert on bbc telling andy marr that president macron and other countries not g  :
#  Negative
# brt datasciencectrl why you should use big data analytics in recruitment by tobias foster   :
#  Negative
# b one example of the people who have been pushing corona failed policies why would we follow a dictatorship like ccple :
#  Negative
# b the department of homeland security dhs is being sued by center for democracy amp technology cdt for failing to respond t :
#  Positive
# b merck challenges safety amp validity of all ivermectin studies for covid19 despite having donated billions of doses to less :
#  Negative
# b mfs scared of government chips being implanted inside of us as if we dont walk around with 1000 data collecting farms in :
#  Negative
# b    my point is its data is useful :
#  Negative
# b the most exciting part about being a data science specialized solutions engineer  :
#  Positive
# bmain data source dostpagasa as of 4 pm phstnmodel references ecmwf gfsnprepared by r villanueva masd :
#  Positive
# b somnies attentionnnwe are not done yet we still have show champion and we cant drop off the charts at all until 2359k :
#  Positive
# b         :
#  Positive
# bearly years settings are open to all children including those of stay at home parents :
#  Positive
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b third and last day well track shoseki one piece holds its position phantom seer even manages to climb 1 place in the rank :
#  Positive
# b covid19nncovid194250035600 :
#  Negative
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# b todos los que piden el cierre total de la hostelera y del comercio sin excepcin viven de un sueldo fijo esto facilit :
#  Positive
# bwhatshappeninginmaynmar nfightfordemocracy :
#  Negative
# b  ive used 5568 gb data since 10 iannnsidnaaz mvs in 100m club :
#  Negative
# b under 12 hour warning ndata collection for most shows ends in less than 12 hours along with the prevoting on ido :
#  Negative
# b for this piece i tried to gather together some thoughts about the serosurvey data coming out of india there is a great d :
#  Negative
# b join free odscwebinar to learn how to make utilization of opensource project dbt in order to build data pipelines for internal :
#  Negative
# b data giveaway by  nfollow him to benefit this sunday morningnnmake sure you rt :
#  Negative
# b massive study shows nnno instances of childto adult transmission of sarscov2 were reported within schoolsnnteachers un :
#  Negative
# b i had someone tell me the other day china has done better than the us at the coronavirus i said based on whos data :
#  Negative
# b hijabpaket data dan tiktok :
#  Positive
# b notable that az are open that they just dont have data on severe disease  the below is plausible i think but still not c :
#  Negative
# b thread internet in myanmar and the role of social media for the prodemocracy movement we know the military has severely :
#  Negative
# b i cant imagine a better group of folks to learn data science from  :
#  Negative
# b 201610nn 2093n 1798n 950n 580n580n 452n 435n 56nnhttps :
#  Negative
# bsarscov2infekte in deutschland grafik oben n5 feb 181 879 n6 feb 181 464nanzahl der aktuell sarscov2  :
#  Positive
# b  macho que vives en manchester  :
#  Negative
# b alahai nnkalo sokong pakatan harapan yg atok jadi pm mengapa nak pinda perlembagaan utk kembalikan hak sarawak dan sa :
#  Positive
# b this week professionalising data stewardship in the netherlands competences training and education was published rea :
#  Positive
# b the movie  johnnys webnn  :
#  Negative
# b            :
#  Positive
# bhi  nive been with you for thirty years nplease dont advertise with gb news or any other similar fox ne  :
#  Negative
# b hampir setahun 800 triliun dua juta data belum tercatat nnsebelumnya bisa sembuh sendirinnsemangatnnmerawatingat ht :
#  Negative
# b read the best account of why merck disavowed ivermectin a cold hard business decision with an element of strategic scar :
#  Positive
# b nnn  :
#  Negative
# b trial data also showing fewer asymptomatic infections which likely points to reduced transmission following vaccination :
#  Negative
# b  pengembangan negara maju dan berkembang bimbingan alumni ui nndisclaimer  jawaban ini ga 100 benar jadi kalau ada y :
#  Positive
# b 4 dr fauci the data really are quite suggestive the level of immunity that you get from natural infection  either the :
#  Negative
# b join free odscwebinar to learn how to make utilization of opensource project dbt in order to build data pipelines for internal :
#  Negative
# b update a neartotal internet shutdown is now in effect in myanmarnnnetwork data show a collapse of connectivity to 16 of :
#  Negative
# b  cara menyelamatkan filedatadata dari laptop yang sudah rusakmati total nna thread  :
#  Negative
# b massive study shows nnno instances of childto adult transmission of sarscov2 were reported within schoolsnnteachers un :
#  Negative
# b arria provides human language enhancing data amp voice reports in excel powerbi alexa qlik resultsbi uipath tibco ta :
#  Positive
# b merck challenges safety amp validity of all ivermectin studies for covid19 despite having donated billions of doses to l :
#  Negative
# b so i wrote a 5400word lecture note on the basics of data engineering for my students coveringnn data formats row vs colu :
#  Negative
# b really interesting data discussed at gm4women2028 nnwe encourage  to breakdown the score card by single :
#  Positive
# b we are focused on school shootings why not this our politicians copied policies of the ccp because the medical indu :
#  Negative
# b    95     nn    2019      8        :
#  Negative

# %%
import numpy as no

labels.label()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-b5a962330257> in <module>()
#       1 import numpy as no
#       2
# ----> 3 labels.label()
#
# AttributeError: 'list' object has no attribute 'label'
